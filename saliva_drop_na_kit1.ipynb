# %% [raw]
# #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# # File name: saliva_drop_na_kit1
# # Date: 2025.10.02
# # Programmer: Barbara Nowak
# # Purpose: Drop missing saliva samples in kit1, check that Primiparous = TRUE (nulliparous), and write to separate files
# #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
library(tidyverse)
library(dplyr)
# Out:
# ── Attaching core tidyverse packages ─────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.6
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.1     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ───────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# ## File reading============================================================================================================================================================

# %% [raw]
# saliva_samples <- read.csv("/ceph/projects/010_SweMaMi/bm.nowak/data/saliva_samples_250923.csv", header = TRUE)
# dim(saliva_samples)
# head(saliva_samples)

# %%
fp_saliva <- read.csv("/ceph/projects/010_SweMaMi/bm.nowak/unfiltered_divided_data/2025-07-29_kit_fp_.csv", header = TRUE, row.names = 1)
head(fp_saliva)
dim(fp_saliva)
# Out:
#      Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb
# 5265 Scf5931f     NA         0        0         0
# 5254 S14e664f     NA         0        0         1
# 5367 S194e21b     NA         0        0         0
# 5297 S1a267fa     NA         0        0         0
# 5300 S30bce16     NA         0        0         0
# 5208 Sa8397fa     NA         0        0         0
#      Q1_Datum   Q1_Personnummer Avbruten_graviditet age_checked Age_groups ⋯
# 5265 2018-12-13 P060d440        0                   30          3          ⋯
# 5254 2018-09-10 P14e664f        0                   30          3          ⋯
# 5367 2018-11-16 P159f9c8        0                   36          4          ⋯
# 5297 2019-05-23 P1a267fa        0                   32          3          ⋯
# 5300 2018-04-18 P1d75300        0                   32          3          ⋯
# 5208 2018-03-14 P1ef420d        0                   27          2          ⋯
# ...

# %%
sp_saliva <- read.csv("/ceph/projects//010_SweMaMi/bm.nowak/unfiltered_divided_data/2025-07-29_kit_sp_.csv", header = TRUE, row.names = 1)
head(sp_saliva)
dim(sp_saliva)
# Out:
#      Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb
# 5253 S060d440     NA         0        0         1
# 5290 Sefe71fe     NA         0        0         1
# 5391 S159f9c8     NA         0        0         0
# 5332 Sb124b17     NA         0        0         2
# 5322 S1d75300     NA         0        0         0
# 5247 S1ef420d     NA         0        0         1
#      Q1_Datum   Q1_Personnummer Avbruten_graviditet age_checked Age_groups ⋯
# 5253 2019-06-03 P060d440        0                   30          3          ⋯
# 5290 2020-08-17 P14e664f        0                   32          3          ⋯
# 5391 2021-01-28 P159f9c8        0                   38          4          ⋯
# 5332 2021-01-06 P1a267fa        0                   34          3          ⋯
# 5322 2019-05-14 P1d75300        0                   33          3          ⋯
# 5247 2020-09-17 P1ef420d        0                   30          3          ⋯
# ...

# %%
#sp_saliva |> filter(is.na(kit1.salival_sample.barcode))
sp_saliva$kit2.salival_sample.barcode
# Out:
#  [1] 17683    NA    NA    NA 16603    NA 15399    NA    NA 18117    NA    NA
# [13] 17232    NA 17360    NA    NA    NA    NA    NA    NA    NA    NA    NA
# [25] 17856 19335 18192    NA    NA 20042 20183    NA    NA    NA    NA 23815
# [37] 21521 21481    NA    NA    NA 16762    NA    NA    NA    NA    NA    NA
# [49]    NA 17263 17491    NA    NA    NA 19613 19539 19008    NA 19677

# %%
grep("kit", names(fp_saliva), value = TRUE)
# Out:
#  [1] "kit1.faecal_sample.barcode"
#  [2] "kit2.faecal_sample.barcode"
#  [3] "kit3.faecal_sample.barcode"
#  [4] "kit3.infant_faecal_sample.barcode"
#  [5] "kit3.infant_faecal_sample_2.barcode"
#  [6] "kit3.salival_sample.barcode"
#  [7] "kit1.salival_sample.barcode"
#  [8] "kit1.vaginal_sample.barcode"
#  [9] "kit1.faecal_sample.datetime_taken"
# [10] "kit1.salival_sample.datetime_taken"
# [11] "kit1.vaginal_sample.datetime_taken"
# [12] "kit2.salival_sample.barcode"
# [13] "kit2.vaginal_sample.barcode"
# [14] "kit2.faecal_sample.datetime_taken"
# [15] "kit2.salival_sample.datetime_taken"
# [16] "kit2.vaginal_sample.datetime_taken"
# [17] "kit3.vaginal_sample.barcode"
# [18] "kit3.faecal_sample.datetime_taken"
# [19] "kit3.infant_faecal_sample.datetime_taken"
# [20] "kit3.infant_faecal_sample_2.datetime_taken"
# [21] "kit3.salival_sample.datetime_taken"
# [22] "kit3.vaginal_sample.datetime_taken"

# %% [markdown]
# ## Kit1-------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Find pn where kit1_saiva is missing
pn_fp_tp1 <- fp_saliva |>
  filter(is.na(kit1.salival_sample.barcode)) |>
  pull(Q1_Personnummer)
pn_fp_tp1
length(pn_fp_tp1)
# Out:
# [1] "P159f9c8" "P428e1c4" "Pc10d0b0" "Pc99e873"
# [1] 4

# %%
pn_sp_tp1 <- sp_saliva |>
    filter(is.na(kit1.salival_sample.barcode)) |>
    pull(Q1_Personnummer)
pn_sp_tp1
length(pn_sp_tp1)
# Out:
#  [1] "P159f9c8" "P1a267fa" "P1ef420d" "P1f95844" "P3c0f6ee" "P3cac7b0"
#  [7] "P42f2c08" "P43d1efc" "P46f36c7" "P4a05456" "P4eaf499" "P62ea0b2"
# [13] "P7b2ccf8" "P97574f9" "P9cdfd5a" "Pa8747ea" "Pbdbd455" "Pbe04f9f"
# [19] "Pbe289c8" "Pc3a5016" "Pc44e366" "Pc75b32a" "Pd3b97e6" "Pfb279f0"
# [1] 24

# %%
# combine participants to drop
drop_pn_combined <- c(pn_fp_tp1, pn_sp_tp1)
unique(drop_pn_combined) |> length()
# Out:
# [1] 27

# %% [raw]
# # Remove participants with missing TP1 faecal samples
# # If the barcode is missing in either fp or sp, both entries are dropped.

# %%
fp_tp1_saliva <- fp_saliva |>
    filter(!(Q1_Personnummer %in% drop_pn_combined))
head(fp_tp1_saliva)
dim(fp_tp1_saliva)
# Out:
#   Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb Q1_Datum
# 1 Scf5931f     NA         0        0         0                     2018-12-13
# 2 S14e664f     NA         0        0         1                     2018-09-10
# 3 S30bce16     NA         0        0         0                     2018-04-18
# 4 S1f862a6     NA         0        0         0                     2018-03-07
# 5 S765e59d     NA         0        0         1                     2018-04-20
# 6 S3780ac4     NA         0        0         0                     2019-02-23
#   Q1_Personnummer Avbruten_graviditet age_checked Age_groups ⋯ diffdays
# 1 P060d440        0                   30          3          ⋯ NA
# 2 P14e664f        0                   30          3          ⋯  0
# 3 P1d75300        0                   32          3          ⋯ NA
# 4 P1f862a6        0                   32          3          ⋯  0
# 5 P3399626        0                   36          4          ⋯  0
# ...

# %%
sp_tp1_saliva <- sp_saliva |>
    filter(!(Q1_Personnummer %in% drop_pn_combined))
head(sp_tp1_saliva)
dim(sp_tp1_saliva)
# Out:
#   Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb Q1_Datum
# 1 S060d440     NA         0        0         1                     2019-06-03
# 2 Sefe71fe     NA         0        0         1                     2020-08-17
# 3 S1d75300     NA         0        0         0                     2019-05-14
# 4 Sa79a719     NA         0        0         1                     2019-01-17
# 5 S3399626     NA         0        0         1                     2020-11-04
# 6 Scdb718f     NA         0        0         1                     2020-01-10
#   Q1_Personnummer Avbruten_graviditet age_checked Age_groups ⋯ diffdays
# 1 P060d440        0                   30          3          ⋯  0
# 2 P14e664f        0                   32          3          ⋯  0
# 3 P1d75300        0                   33          3          ⋯ NA
# 4 P1f862a6        0                   32          3          ⋯  0
# 5 P3399626        0                   38          4          ⋯  0
# ...

# %%
# Write to file
#write.table(combined_fp_sp, file = paste0("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/saliva/tp1_filtered/", Sys.Date(), "_combined_fp_sp_tp2", ".csv"), sep = ",", row.names = FALSE)

# %% [markdown]
# ## Missing birthweight drop ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Find fp women where birth date of child is missing
# Why did we do this? oR why would the weight be missing?
pn_fp_missing_birthdate <- fp_tp1_saliva |>
  filter(is.na(fodelsedatum_barn)) |>
  pull(Q1_Personnummer)
pn_fp_missing_birthdate
# Out:
#  [1] "P060d440" "P1d75300" "P3780ac4" "P6d2ebc4" "P7f1746e" "Pab443f9"
#  [7] "Pb752955" "Pc9a3575" "Pd01a0ba" "Pe3450d3" "Pf573f67" "Pff3c644"

# %%
# Find women where birth weight is missing
grep("weight", names(fp_tp1_saliva), value = TRUE)
pn_fp_missing_birthweight <- fp_tp1_saliva |>
    filter(is.na(Birthweight_checked)) |>
    pull(Q1_Personnummer)
pn_fp_missing_birthweight
# Out:
# [1] "Birthweight_checked" "excess_weight"
#  [1] "P060d440" "P1d75300" "P3780ac4" "P6d2ebc4" "P7f1746e" "Pab443f9"
#  [7] "Pb752955" "Pd01a0ba" "Pe3450d3" "Pff3c644"

# %%
setdiff(pn_fp_missing_birthdate,pn_fp_missing_birthweight)
# Out:
# [1] "Pc9a3575" "Pf573f67"

# %%
intersect(pn_fp_missing_birthdate, drop_pn_combined)
# Out:
# character(0)

# %% [raw]
# # Drop participants with missing birthdate
# fp_tp1_saliva_adjusted <- fp_tp1_saliva |>
#     filter(!(Q1_Personnummer %in% pn_fp_missing_birthdate))
# head(fp_tp1_saliva_adjusted)
# dim(fp_tp1_saliva_adjusted)

# %%
# Drop participants with missing birthweight
fp_tp1_saliva_adjusted <- fp_tp1_saliva |>
    filter(!(Q1_Personnummer %in% pn_fp_missing_birthweight))
head(fp_tp1_saliva_adjusted)
dim(fp_tp1_saliva_adjusted)
# Out:
#   Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb Q1_Datum
# 1 S14e664f     NA         0        0         1                     2018-09-10
# 2 S1f862a6     NA         0        0         0                     2018-03-07
# 3 S765e59d     NA         0        0         1                     2018-04-20
# 4 S39fe1d7     NA         0        0         0                     2018-06-23
# 5 S7e4a963     NA         0        0         0                     2018-02-18
# 6 S5fa4a39     NA         0        0         0                     2018-08-30
#   Q1_Personnummer Avbruten_graviditet age_checked Age_groups ⋯ diffdays
# 1 P14e664f        0                   30          3          ⋯ 0
# 2 P1f862a6        0                   32          3          ⋯ 0
# 3 P3399626        0                   36          4          ⋯ 0
# 4 P3db7da6        0                   29          2          ⋯ 0
# 5 P424fd61        0                   37          4          ⋯ 0
# ...

# %% [markdown]
# ## Nulliparous selection--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# # FInd women where primipara = True for fp

# %%
# Find all primipara personal# from fp
pn_primipara_fp <- fp_tp1_saliva_adjusted |>
    filter(fp_tp1_saliva_adjusted$Primipara == 1) |>
    pull(Q1_Personnummer)
pn_primipara_fp
pn_fp_missing_birthdate
# Out:
#  [1] "P1f862a6" "P3db7da6" "P424fd61" "P4de45e7" "P50f102c" "P5b98b6c"
#  [7] "P719b21e" "P735d77f" "P7ece52e" "P92b4604" "Pa8f3b51" "Pbbb08bd"
# [13] "Pc77a35c" "Pc9a3575" "Pca94a0f" "Pcd2c0d1" "Pdab1897" "Pe706703"
# [19] "Pf573f67"
#  [1] "P060d440" "P1d75300" "P3780ac4" "P6d2ebc4" "P7f1746e" "Pab443f9"
#  [7] "Pb752955" "Pc9a3575" "Pd01a0ba" "Pe3450d3" "Pf573f67" "Pff3c644"

# %%
intersect(pn_primipara_fp, pn_fp_missing_birthdate)
# Out:
# [1] "Pc9a3575" "Pf573f67"

# %%
# Keep only participants that are primiparous
fp_nulliparous <- fp_tp1_saliva_adjusted |>
  filter(Q1_Personnummer %in% pn_primipara_fp) 
head(fp_nulliparous)
dim(fp_nulliparous)
# Out:
#   Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb Q1_Datum
# 1 S1f862a6     NA         0        0         0                     2018-03-07
# 2 S39fe1d7     NA         0        0         0                     2018-06-23
# 3 S7e4a963     NA         0        0         0                     2018-02-18
# 4 S5fa4a39     NA         0        0         0                     2018-08-30
# 5 S50f102c     NA         0        0         0                     2018-08-05
# 6 S5b98b6c     NA         0        0         0                     2018-04-03
#   Q1_Personnummer Avbruten_graviditet age_checked Age_groups ⋯ diffdays
# 1 P1f862a6        0                   32          3          ⋯ 0
# 2 P3db7da6        0                   29          2          ⋯ 0
# 3 P424fd61        0                   37          4          ⋯ 0
# 4 P4de45e7        0                   29          2          ⋯ 0
# 5 P50f102c        0                   32          3          ⋯ 0
# ...

# %%
pn_filtered <- fp_nulliparous |>
  pull(Q1_Personnummer)
pn_filtered
length(pn_filtered)
# Out:
#  [1] "P1f862a6" "P3db7da6" "P424fd61" "P4de45e7" "P50f102c" "P5b98b6c"
#  [7] "P719b21e" "P735d77f" "P7ece52e" "P92b4604" "Pa8f3b51" "Pbbb08bd"
# [13] "Pc77a35c" "Pc9a3575" "Pca94a0f" "Pcd2c0d1" "Pdab1897" "Pe706703"
# [19] "Pf573f67"
# [1] 19

# %%
# Keep sp participants primiparous in fp
sp_nulliparous <- sp_tp1_saliva |>
  filter(Q1_Personnummer %in% pn_filtered)
head(sp_nulliparous)
dim(sp_nulliparous)
# Out:
#   Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb Q1_Datum
# 1 Sa79a719     NA         0        0         1                     2019-01-17
# 2 S3db7da6     NA         0        0         1                     2019-09-24
# 3 S424fd61     NA         0        0         0                     2020-11-03
# 4 S4de45e7     NA         0        0         0                     2020-11-05
# 5 Sa957143     NA         0        0         1                     2020-07-11
# 6 S0332ad6     NA         0        0         0                     2020-06-05
#   Q1_Personnummer Avbruten_graviditet age_checked Age_groups ⋯ diffdays
# 1 P1f862a6        0                   32          3          ⋯  0
# 2 P3db7da6        0                   30          3          ⋯  0
# 3 P424fd61        0                   40          4          ⋯ 31
# 4 P4de45e7        0                   31          3          ⋯  0
# 5 P50f102c        0                   34          3          ⋯  0
# ...

# %% [raw]
# # This I should maybe do in kit 2 check since it will make things less confusing
# pn_check2 <- sp_nulliparous |>
#   filter(is.na(fodelsedatum_barn)) |>
#   pull(Q1_Personnummer)
# pn_check2

# %%
# Doubble check that all are no longer primiparous in sp
pn_check <- sp_nulliparous |> 
  filter(sp_nulliparous$Primipara == 1) |>
  pull(Q1_Personnummer)
pn_check
length(pn_check)
#sp_nulliparous |> 
 # filter(sp_nulliparous$Primipara == 1) |> pull(Primipara)
# Out:
# [1] "Pc9a3575"
# [1] 1

# %%
# One participant was marked as nulliparous twice, crossed week 24 but the baby did not make it
fp_saliva |> filter(fp_saliva$Q1_Personnummer == "Pc9a3575") 
sp_saliva |> filter(sp_saliva$Q1_Personnummer == "Pc9a3575")
# Out:
#   Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb Q1_Datum
# 1 Sc9a3575     NA         0        0         0                     2018-01-31
#   Q1_Personnummer Avbruten_graviditet age_checked Age_groups ⋯ diffdays
# 1 Pc9a3575        0                   30          3          ⋯ NA
#   missfall.IUFD_week IUFD missfall
# 1 24                 0    0
#   missfall.IUFD_comments
# 1 IUFD Jag fick havandeskapsförgiftning i v.22 och var tvungen att bli igångsatt. Flickan föddes i v. 24 +0 och överlevde tyvärr inte.
#   Gest_w_combined deliv_start_combined Type_of_PTB s_PTB
# 1 24              Induction            NA          NA
#   preeclampsia_epi_analysis
# 1 1
#   Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb Q1_Datum
# 1 S99e6192     NA         0        0         1                     2020-05-15
#   Q1_Personnummer Avbruten_graviditet age_checked Age_groups ⋯ diffdays
# 1 Pc9a3575        0                   32          3          ⋯ 0
# ...

# %%
fp_saliva |> filter(fp_saliva$Q1_Personnummer == "Pc9a3575")  |> pull(Primipara)
sp_saliva |> filter(sp_saliva$Q1_Personnummer == "Pc9a3575")  |> pull(Primipara)
# Out:
# [1] 1
# [1] 1

# %%
fp_saliva |> filter(fp_saliva$Q1_Personnummer == "Pc9a3575")  |> pull(Studienummer)
sp_saliva |> filter(sp_saliva$Q1_Personnummer == "Pc9a3575")  |> pull(Studienummer)
# Out:
# [1] "Sc9a3575"
# [1] "S99e6192"

# %%
# The participant needs to be marked as multiparous for sp since 
sp_nulliparous$Primipara[sp_nulliparous$Q1_Personnummer == "Pc9a3575"] <- 0
sp_nulliparous |> filter(sp_nulliparous$Q1_Personnummer == "Pc9a3575")  |> pull(Primipara)
# Out:
# [1] 0

# %%
dim(sp_nulliparous)
# Out:
# [1]  19 565

# %% [markdown]
# ## Write to file------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Ad column with group
fp_nulliparous$Group <- "First pregnancy "
sp_nulliparous$Group <- "Second pregnancy"

# %%
# Merge the two df vertically:
combined_fp_sp <- rbind(fp_nulliparous, sp_nulliparous)
dim(combined_fp_sp)
head(combined_fp_sp)
# Out:
# [1]  38 566
#   Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb Q1_Datum
# 1 S1f862a6     NA         0        0         0                     2018-03-07
# 2 S39fe1d7     NA         0        0         0                     2018-06-23
# 3 S7e4a963     NA         0        0         0                     2018-02-18
# 4 S5fa4a39     NA         0        0         0                     2018-08-30
# 5 S50f102c     NA         0        0         0                     2018-08-05
# 6 S5b98b6c     NA         0        0         0                     2018-04-03
#   Q1_Personnummer Avbruten_graviditet age_checked Age_groups ⋯
# 1 P1f862a6        0                   32          3          ⋯
# 2 P3db7da6        0                   29          2          ⋯
# 3 P424fd61        0                   37          4          ⋯
# 4 P4de45e7        0                   29          2          ⋯
# 5 P50f102c        0                   32          3          ⋯
# ...

# %%
# Write to file
write.table(fp_nulliparous, file = paste0("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/saliva/tp1_nulliparous/", Sys.Date(), "fp_tp1_nulliparous_saliva", ".csv"), sep = ",", row.names = FALSE)
write.table(sp_nulliparous, file = paste0("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/saliva/tp1_nulliparous/", Sys.Date(), "sp_tp1_nulliparous_saliva", ".csv"), sep = ",", row.names = FALSE)

write.table(combined_fp_sp, file = paste0("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/saliva/tp1_nulliparous/", Sys.Date(), "_combined_nulliparous_fp_sp_tp1_saliva", ".csv"), sep = ",", row.names = FALSE)

# %%
#grep("Q2_X2.4_Any", names(sp_nulliparous), value = TRUE)
#p_saliva$Q2_X2.4_Anything_gone_wrong

# %% [raw]
# # Create files fp_tp1_saliva and sp_tp1_saliva
# # This is just for flow cell filtration as Primiparity is not important, neither is missing any other condition

# %%
# Merge the two df vertically:
combined_for_flowcells <- rbind(fp_tp1_saliva, sp_tp1_saliva)
dim(combined_for_flowcells)
head(combined_for_flowcells)
# Out:
# [1]  64 565
#   Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb Q1_Datum
# 1 Scf5931f     NA         0        0         0                     2018-12-13
# 2 S14e664f     NA         0        0         1                     2018-09-10
# 3 S30bce16     NA         0        0         0                     2018-04-18
# 4 S1f862a6     NA         0        0         0                     2018-03-07
# 5 S765e59d     NA         0        0         1                     2018-04-20
# 6 S3780ac4     NA         0        0         0                     2019-02-23
#   Q1_Personnummer Avbruten_graviditet age_checked Age_groups ⋯ diffdays
# 1 P060d440        0                   30          3          ⋯ NA
# 2 P14e664f        0                   30          3          ⋯  0
# 3 P1d75300        0                   32          3          ⋯ NA
# 4 P1f862a6        0                   32          3          ⋯  0
# 5 P3399626        0                   36          4          ⋯  0
# ...

# %%
write.table(combined_for_flowcells, file = paste0("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/saliva/tp1_nulliparous/", Sys.Date(), "combined_for_flowcells_saliva", ".csv"), sep = ",", row.names = FALSE)

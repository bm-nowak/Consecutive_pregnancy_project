# %% [raw]
# #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# # File name: double_pregnancy_convert
# # Date: 2025.07.29
# # Programmer: Barbara Nowak
# # Purpose: Copy fp and sp data to different files
# #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
library(tidyverse)
library(dplyr)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Out:
# ── Attaching core tidyverse packages ────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.2
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ──────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
double_pregnancy <- read.csv("/ceph/projects/010_SweMaMi/bm.nowak/data/double_pregnancy_240913.csv", header = TRUE)
#double_pregnancy |> summary()
#glimpse(double_pregnancy)
head(double_pregnancy)
# Out:
#   X    Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb
# 1 5199 Sc10d0b0     NA         1        0         3
# 2 5200 S735d77f     NA         0        0         0
# 3 5201 S9cdfd5a     NA         0        0         0
# 4 5202 S9026714     NA         0        0         2
# 5 5204 S9deb4a6     NA         0        0         0
# 6 5205 S7b1a87b     NA         1        0         4
#   Q1_Datum            Q1_Personnummer Avbruten_graviditet age_checked ⋯
# 1 2018-10-16 13:07:00 Pc10d0b0        0                   25          ⋯
# 2 2018-08-24 12:23:00 P735d77f        0                   25          ⋯
# 3 2018-08-14 07:21:00 P9cdfd5a        0                   25          ⋯
# 4 2019-01-02 18:05:00 P7ece52e        0                   25          ⋯
# 5 2019-11-20 20:13:00 P735d77f        0                   26          ⋯
# 6 2019-05-28 12:01:00 Pc10d0b0        0                   26          ⋯
#   diffdays missfall.IUFD_week IUFD missfall missfall.IUFD_comments
# ...

# %%
# 2 Convert char Q1_Datum to date format
double_pregnancy$Q1_Datum <- as.Date(double_pregnancy$Q1_Datum)

# %%
# 3 sort file; group duplicate Q1_Personnummer by date
sorted_double_pregnancy <- double_pregnancy |>
  arrange(Q1_Personnummer, Q1_Datum)
#glimpse(sorted_double_pregnancy)

# %%
# 3 Extract first and second pregnancy
kit_fp <- sorted_double_pregnancy |>
  group_by(Q1_Personnummer) |>
  slice(1)

# %%
kit_sp <- sorted_double_pregnancy |>
  group_by(Q1_Personnummer) |>
  slice(2)

# %%
# Check that num of rows and columns is still correct
dim(kit_fp)
dim(kit_sp)
# Out:
# [1]  59 566
# [1]  59 566

# %%
# Check dates and pers# are correct
head(kit_fp)
head(kit_sp)
# Out:
#   X    Studienummer Correct_PN Prev_RPL Prev_IUFD Prev_miscarriage_numb
# 1 5265 Scf5931f     NA         0        0         0
# 2 5254 S14e664f     NA         0        0         1
# 3 5367 S194e21b     NA         0        0         0
# 4 5297 S1a267fa     NA         0        0         0
# 5 5300 S30bce16     NA         0        0         0
# 6 5208 Sa8397fa     NA         0        0         0
#   Q1_Datum   Q1_Personnummer Avbruten_graviditet age_checked ⋯ diffdays
# 1 2018-12-13 P060d440        0                   30          ⋯ NA
# 2 2018-09-10 P14e664f        0                   30          ⋯  0
# 3 2018-11-16 P159f9c8        0                   36          ⋯  0
# 4 2019-05-23 P1a267fa        0                   32          ⋯  0
# 5 2018-04-18 P1d75300        0                   32          ⋯ NA
# 6 2018-03-14 P1ef420d        0                   27          ⋯  0
#   missfall.IUFD_week IUFD missfall missfall.IUFD_comments Gest_w_combined
# ...

# %%
# 5 write to file
write.table(kit_fp, file = paste0(Sys.Date(), "_kit_fp_", ".csv"), sep = ",", row.names = FALSE)
write.table(kit_sp, file = paste0(Sys.Date(), "_kit_sp_", ".csv"), sep = ",", row.names = FALSE)

# %%
# Test file looks ok
#test_kit_fp <- read.csv("~/Programs/Programing_experiments/R/HT25_project/2025-07-29_kit_fp_.csv", header = TRUE)
#test_kit_sp <- read.csv("~/Programs/Programing_experiments/R/HT25_project/2025-07-29_kit_sp_.csv", header = TRUE)

# %%
#glimpse(test_kit_fp)

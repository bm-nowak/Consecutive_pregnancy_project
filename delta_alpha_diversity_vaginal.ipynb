# %% [raw]
# #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# # File name: delta_alpha_diversity_vaginal
# # Date: 2025.11.13
# # Programmer: Barbara Nowak
# # Purpose: Vaginal, To calculate the delta alpha diversity for Fp and Sp respectively
# #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
library(ggplot2)
library(tidyverse)
library(dplyr)
library(vegan)
library(cowplot)
library(see)
library(ggstatsplot)
library(ggeffects)
# Out:
# You can cite this package as:
#      Patil, I. (2021). Visualizations with statistical details: The 'ggstatsplot' approach.
#      Journal of Open Source Software, 6(61), 3167, doi:10.21105/joss.03167

# %% [markdown]
# # File reading=========================================================================================================================================

# %%
tp1_shannon_combined <- read.csv("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/vaginal/tp1_nulliparous/tp1_alpha_beta_diversity/alpha/2025-11-12_tp1_shannon.csv", 
                                 header = TRUE)
dim(tp1_shannon_combined)
head(tp1_shannon_combined)
# Out:
# [1] 52  4
#   Sample_ID  Shannon    Group       Personal_number
# 1 FF00653546 0.13195913 Nulliparous P159f9c8
# 2 FB02825409 1.29491833 Nulliparous P1f862a6
# 3 FF02015345 0.79838981 Nulliparous P1f95844
# 4 FF00653065 0.08743932 Nulliparous P3cac7b0
# 5 FF02014263 0.00411877 Nulliparous P3db7da6
# 6 FF02015432 0.78158728 Nulliparous P424fd61

# %%
tp2_shannon_combined <- read.csv("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/vaginal/tp2_nulliparous/tp2_alpha_beta_diversity/alpha/2025-11-12_tp2_shannon.csv", header = TRUE)
dim(tp2_shannon_combined)
head(tp2_shannon_combined)
# Out:
# [1] 32  4
#   Sample_ID  Shannon    Group       Personal_number
# 1 FF02740612 0.76653316 Nulliparous P159f9c8
# 2 FF02014450 0.03229818 Nulliparous P1f95844
# 3 FF02014344 0.66269445 Nulliparous P3cac7b0
# 4 FF03816858 0.15667443 Nulliparous P3db7da6
# 5 FF02557245 0.47500754 Nulliparous P424fd61
# 6 FF02015423 0.17692788 Nulliparous P4de45e7

# %%
tp1_richness_combined <- read.csv("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/vaginal/tp1_nulliparous/tp1_alpha_beta_diversity/alpha/2025-11-12_tp1_richness.csv", 
                                  header = TRUE)
dim(tp1_richness_combined)
head(tp1_richness_combined)
# Out:
# [1] 52  4
#   Sample_ID  Species_richness Group       Personal_number
# 1 FF00653546 29               Nulliparous P159f9c8
# 2 FB02825409 24               Nulliparous P1f862a6
# 3 FF02015345 17               Nulliparous P1f95844
# 4 FF00653065  8               Nulliparous P3cac7b0
# 5 FF02014263  3               Nulliparous P3db7da6
# 6 FF02015432 37               Nulliparous P424fd61

# %%
tp2_richness_combined <- read.csv("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/vaginal/tp2_nulliparous/tp2_alpha_beta_diversity/alpha/2025-11-12_tp2_richness.csv", header = TRUE)
dim(tp2_richness_combined)
head(tp2_richness_combined)
# Out:
# [1] 32  4
#   Sample_ID  Species_richness Group       Personal_number
# 1 FF02740612 16               Nulliparous P159f9c8
# 2 FF02014450 15               Nulliparous P1f95844
# 3 FF02014344 11               Nulliparous P3cac7b0
# 4 FF03816858  6               Nulliparous P3db7da6
# 5 FF02557245  5               Nulliparous P424fd61
# 6 FF02015423 11               Nulliparous P4de45e7

# %%
tp1_evenness_combined <- read.csv("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/vaginal/tp1_nulliparous/tp1_alpha_beta_diversity/alpha/2025-11-13_tp1_evenness.csv", 
                                  header = TRUE)
dim(tp1_evenness_combined)
head(tp1_evenness_combined)
# Out:
# [1] 52  4
#   Sample_ID  Evenness    Group       Personal_number
# 1 FF00653546 0.039188457 Nulliparous P159f9c8
# 2 FB02825409 0.407456387 Nulliparous P1f862a6
# 3 FF02015345 0.281796573 Nulliparous P1f95844
# 4 FF00653065 0.042049425 Nulliparous P3cac7b0
# 5 FF02014263 0.003749066 Nulliparous P3db7da6
# 6 FF02015432 0.216451135 Nulliparous P424fd61

# %%
tp2_evenness_combined <- read.csv("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/vaginal/tp2_nulliparous/tp2_alpha_beta_diversity/alpha/2025-11-12_tp2_evenness.csv", 
                                  header = TRUE)
dim(tp2_evenness_combined)
head(tp2_evenness_combined)
# Out:
# [1] 32  4
#   Sample_ID  Evenness   Group       Personal_number
# 1 FF02740612 0.27646840 Nulliparous P159f9c8
# 2 FF02014450 0.01192673 Nulliparous P1f95844
# 3 FF02014344 0.27636505 Nulliparous P3cac7b0
# 4 FF03816858 0.08744167 Nulliparous P3db7da6
# 5 FF02557245 0.29513878 Nulliparous P424fd61
# 6 FF02015423 0.07378466 Nulliparous P4de45e7

# %%
# Simpson
tp1_simpson_combined <- read.csv("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/vaginal/tp1_nulliparous/tp1_alpha_beta_diversity/alpha/2025-11-12_tp1_simpson.csv", 
                                 header = TRUE)
dim(tp1_simpson_combined)
head(tp1_simpson_combined)
# Out:
# [1] 52  4
#   Sample_ID  Simpson     Group       Personal_number
# 1 FF00653546 0.035194487 Nulliparous P159f9c8
# 2 FB02825409 0.547372652 Nulliparous P1f862a6
# 3 FF02015345 0.457256373 Nulliparous P1f95844
# 4 FF00653065 0.027936140 Nulliparous P3cac7b0
# 5 FF02014263 0.000877703 Nulliparous P3db7da6
# 6 FF02015432 0.264161953 Nulliparous P424fd61

# %%
# Simpson
tp2_simpson_combined <- read.csv("/ceph/projects/010_SweMaMi/bm.nowak/filtered_data/vaginal/tp2_nulliparous/tp2_alpha_beta_diversity/alpha/2025-11-12_tp2_simpson.csv", 
                                 header = TRUE)
dim(tp2_simpson_combined)
head(tp2_simpson_combined)
# Out:
# [1] 32  4
#   Sample_ID  Simpson     Group       Personal_number
# 1 FF02740612 0.509929830 Nulliparous P159f9c8
# 2 FF02014450 0.007213459 Nulliparous P1f95844
# 3 FF02014344 0.407696384 Nulliparous P3cac7b0
# 4 FF03816858 0.058367645 Nulliparous P3db7da6
# 5 FF02557245 0.248208589 Nulliparous P424fd61
# 6 FF02015423 0.059153140 Nulliparous P4de45e7

# %% [markdown]
# # $\Delta\alpha$ diversity=================================================================================================================================

# %% [markdown]
# ## Shannon--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### First pregnancy

# %%
tp1_shannon_combined$Group <- as.factor(tp1_shannon_combined$Group)
head(tp1_shannon_combined)
# Out:
#   Sample_ID  Shannon    Group       Personal_number
# 1 FF00653546 0.13195913 Nulliparous P159f9c8
# 2 FB02825409 1.29491833 Nulliparous P1f862a6
# 3 FF02015345 0.79838981 Nulliparous P1f95844
# 4 FF00653065 0.08743932 Nulliparous P3cac7b0
# 5 FF02014263 0.00411877 Nulliparous P3db7da6
# 6 FF02015432 0.78158728 Nulliparous P424fd61

# %% [raw]
# Need to create a df for Fp and Sp separately

# %%
# Create a df for Fp  tp1
# Need to pick rows only where Group == Nulliparous
df_fp_tp1_shan <- tp1_shannon_combined |> filter(Group == "Nulliparous")
head(df_fp_tp1_shan)
# Out:
#   Sample_ID  Shannon    Group       Personal_number
# 1 FF00653546 0.13195913 Nulliparous P159f9c8
# 2 FB02825409 1.29491833 Nulliparous P1f862a6
# 3 FF02015345 0.79838981 Nulliparous P1f95844
# 4 FF00653065 0.08743932 Nulliparous P3cac7b0
# 5 FF02014263 0.00411877 Nulliparous P3db7da6
# 6 FF02015432 0.78158728 Nulliparous P424fd61

# %%
# Sanity check
# Though why does "Primiparous" appear at all? Even though it's 0???
unique(df_fp_tp1_shan$Group)
table(df_fp_tp1_shan$Group)
# Out:
# [1] Nulliparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#          26           0

# %%
# Create a df for Fp tp2
# Need to pick rows only where Group == Nulliparous
df_fp_tp2_shan <- tp2_shannon_combined |> filter(Group == "Nulliparous")
head(df_fp_tp2_shan)
# Out:
#   Sample_ID  Shannon    Group       Personal_number
# 1 FF02740612 0.76653316 Nulliparous P159f9c8
# 2 FF02014450 0.03229818 Nulliparous P1f95844
# 3 FF02014344 0.66269445 Nulliparous P3cac7b0
# 4 FF03816858 0.15667443 Nulliparous P3db7da6
# 5 FF02557245 0.47500754 Nulliparous P424fd61
# 6 FF02015423 0.17692788 Nulliparous P4de45e7

# %%
# Sanity check
unique(df_fp_tp2_shan$Group)
table(df_fp_tp2_shan$Group)
# Out:
# [1] "Nulliparous"
# Nulliparous
#          16

# %%
dim(df_fp_tp1_shan)
dim(df_fp_tp2_shan)
head(df_fp_tp1_shan)
# Out:
# [1] 26  4
# [1] 16  4
#   Sample_ID  Shannon    Group       Personal_number
# 1 FF00653546 0.13195913 Nulliparous P159f9c8
# 2 FB02825409 1.29491833 Nulliparous P1f862a6
# 3 FF02015345 0.79838981 Nulliparous P1f95844
# 4 FF00653065 0.08743932 Nulliparous P3cac7b0
# 5 FF02014263 0.00411877 Nulliparous P3db7da6
# 6 FF02015432 0.78158728 Nulliparous P424fd61

# %%
# Merge df by Personal number while adding suffixes to columns

merged_df_shan_fp <- merge(df_fp_tp1_shan, df_fp_tp2_shan, by = "Personal_number", suffixes = c("_tp1", "_tp2"))
dim(merged_df_shan_fp)
head(merged_df_shan_fp)
# Out:
# [1] 16  7
#   Personal_number Sample_ID_tp1 Shannon_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF00653546    0.13195913  Nulliparous FF02740612
# 2 P1f95844        FF02015345    0.79838981  Nulliparous FF02014450
# 3 P3cac7b0        FF00653065    0.08743932  Nulliparous FF02014344
# 4 P3db7da6        FF02014263    0.00411877  Nulliparous FF03816858
# 5 P424fd61        FF02015432    0.78158728  Nulliparous FF02557245
# 6 P4de45e7        FF00653167    0.57158167  Nulliparous FF02015423
#   Shannon_tp2 Group_tp2
# 1 0.76653316  Nulliparous
# 2 0.03229818  Nulliparous
# 3 0.66269445  Nulliparous
# 4 0.15667443  Nulliparous
# 5 0.47500754  Nulliparous
# 6 0.17692788  Nulliparous

# %%
# Subtract Nulliparous Tp2 from Tp1
# For each personal number subtract tp1 from tp2
 merged_df_shan_fp$delta <- merged_df_shan_fp$Shannon_tp2 - merged_df_shan_fp$Shannon_tp1
head(merged_df_shan_fp)
# Out:
#   Personal_number Sample_ID_tp1 Shannon_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF00653546    0.13195913  Nulliparous FF02740612
# 2 P1f95844        FF02015345    0.79838981  Nulliparous FF02014450
# 3 P3cac7b0        FF00653065    0.08743932  Nulliparous FF02014344
# 4 P3db7da6        FF02014263    0.00411877  Nulliparous FF03816858
# 5 P424fd61        FF02015432    0.78158728  Nulliparous FF02557245
# 6 P4de45e7        FF00653167    0.57158167  Nulliparous FF02015423
#   Shannon_tp2 Group_tp2   delta
# 1 0.76653316  Nulliparous  0.6345740
# 2 0.03229818  Nulliparous -0.7660916
# 3 0.66269445  Nulliparous  0.5752551
# 4 0.15667443  Nulliparous  0.1525557
# 5 0.47500754  Nulliparous -0.3065797
# 6 0.17692788  Nulliparous -0.3946538

# %%
merged_df_shan_fp |> filter(Personal_number == "P159f9c8")
# Out:
#   Personal_number Sample_ID_tp1 Shannon_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF00653546    0.1319591   Nulliparous FF02740612
#   Shannon_tp2 Group_tp2   delta
# 1 0.7665332   Nulliparous 0.634574

# %% [markdown]
# ### Second pregnancy

# %%
# Create a df for Sp tp1
# Need to pick rows only where Group == Primiparous
df_sp_tp1_shan <- tp1_shannon_combined |> filter(Group == "Primiparous")
head(df_sp_tp1_shan)
dim(df_sp_tp1_shan)
# Out:
#   Sample_ID  Shannon     Group       Personal_number
# 1 FF01566745 0.711353879 Primiparous P159f9c8
# 2 FF06039085 0.020082949 Primiparous P1f862a6
# 3 FF06039601 0.004803629 Primiparous P1f95844
# 4 FF06039627 1.017153045 Primiparous P3cac7b0
# 5 FF03817982 0.593648388 Primiparous P3db7da6
# 6 FF05044855 1.096887824 Primiparous P424fd61
# [1] 26  4

# %%
df_sp_tp1_shan$Group <- as.factor(df_sp_tp1_shan$Group)
class(df_sp_tp1_shan$Group)
# Out:
# [1] "factor"

# %%
# Sanity check
unique(df_sp_tp1_shan$Group)
table(df_sp_tp1_shan$Group)
# Out:
# [1] Primiparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#           0          26

# %%
# Create a df for Sp tp2
# Need to pick rows only where Group == Primiparous
df_sp_tp2_shan <- tp2_shannon_combined |> filter(Group == "Primiparous")
head(df_sp_tp2_shan)
dim(df_sp_tp2_shan)
# Out:
#   Sample_ID  Shannon    Group       Personal_number
# 1 FF08440357 0.06952553 Primiparous P159f9c8
# 2 FF04761496 1.31874981 Primiparous P1f95844
# 3 FF08440702 0.73471326 Primiparous P3cac7b0
# 4 FF05024823 0.69651175 Primiparous P3db7da6
# 5 FF06580149 0.17090115 Primiparous P424fd61
# 6 FF01572330 0.69326607 Primiparous P4de45e7
# [1] 16  4

# %%
df_sp_tp2_shan$Group <- as.factor(df_sp_tp2_shan$Group)
class(df_sp_tp2_shan$Group)
# Out:
# [1] "factor"

# %%
# Sanity check
unique(df_sp_tp2_shan$Group)
table(df_sp_tp2_shan$Group)
# Out:
# [1] Primiparous
# Levels: Primiparous
# Primiparous
#          16

# %%
dim(df_sp_tp1_shan)
dim(df_sp_tp2_shan)
# Out:
# [1] 26  4
# [1] 16  4

# %%
# Merge df by Personal number while adding suffixes to columns

merged_df_shan_sp <- merge(df_sp_tp1_shan, df_sp_tp2_shan, by = "Personal_number", suffixes = c("_tp1", "_tp2"))
dim(merged_df_shan_sp)
head(merged_df_shan_sp)
# Out:
# [1] 16  7
#   Personal_number Sample_ID_tp1 Shannon_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF01566745    0.711353879 Primiparous FF08440357
# 2 P1f95844        FF06039601    0.004803629 Primiparous FF04761496
# 3 P3cac7b0        FF06039627    1.017153045 Primiparous FF08440702
# 4 P3db7da6        FF03817982    0.593648388 Primiparous FF05024823
# 5 P424fd61        FF05044855    1.096887824 Primiparous FF06580149
# 6 P4de45e7        FF06040007    0.662870732 Primiparous FF01572330
#   Shannon_tp2 Group_tp2
# 1 0.06952553  Primiparous
# 2 1.31874981  Primiparous
# 3 0.73471326  Primiparous
# 4 0.69651175  Primiparous
# 5 0.17090115  Primiparous
# 6 0.69326607  Primiparous

# %%
# Do the calculation for Sp and add as column
# Tp2 - tp1
merged_df_shan_sp$delta <- merged_df_shan_sp$Shannon_tp2 - merged_df_shan_sp$Shannon_tp1
head(merged_df_shan_sp)
# Out:
#   Personal_number Sample_ID_tp1 Shannon_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF01566745    0.711353879 Primiparous FF08440357
# 2 P1f95844        FF06039601    0.004803629 Primiparous FF04761496
# 3 P3cac7b0        FF06039627    1.017153045 Primiparous FF08440702
# 4 P3db7da6        FF03817982    0.593648388 Primiparous FF05024823
# 5 P424fd61        FF05044855    1.096887824 Primiparous FF06580149
# 6 P4de45e7        FF06040007    0.662870732 Primiparous FF01572330
#   Shannon_tp2 Group_tp2   delta
# 1 0.06952553  Primiparous -0.64182835
# 2 1.31874981  Primiparous  1.31394618
# 3 0.73471326  Primiparous -0.28243979
# 4 0.69651175  Primiparous  0.10286336
# 5 0.17090115  Primiparous -0.92598667
# 6 0.69326607  Primiparous  0.03039534

# %% [markdown]
# ### Plot----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# # Now need a plot that visualizes this,
# # For that I need a combined df with Primiparous and Nulliparous

# %%
shan_combined_df <- rbind(merged_df_shan_fp, merged_df_shan_sp)
head(shan_combined_df)
# Out:
#   Personal_number Sample_ID_tp1 Shannon_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF00653546    0.13195913  Nulliparous FF02740612
# 2 P1f95844        FF02015345    0.79838981  Nulliparous FF02014450
# 3 P3cac7b0        FF00653065    0.08743932  Nulliparous FF02014344
# 4 P3db7da6        FF02014263    0.00411877  Nulliparous FF03816858
# 5 P424fd61        FF02015432    0.78158728  Nulliparous FF02557245
# 6 P4de45e7        FF00653167    0.57158167  Nulliparous FF02015423
#   Shannon_tp2 Group_tp2   delta
# 1 0.76653316  Nulliparous  0.6345740
# 2 0.03229818  Nulliparous -0.7660916
# 3 0.66269445  Nulliparous  0.5752551
# 4 0.15667443  Nulliparous  0.1525557
# 5 0.47500754  Nulliparous -0.3065797
# 6 0.17692788  Nulliparous -0.3946538

# %%
dim(shan_combined_df)
# Out:
# [1] 32  8

# %% [raw]
# On the x axis should be Tp1 and Tp2 and these should be divided in Fp and Sp
# Easier to do if df is reshaped

# %%
# Reshape df into long format for easier plotting

df_shan_long <- shan_combined_df |>
    select(Personal_number, Shannon_tp1, Shannon_tp2, Group_tp2, delta) |>
pivot_longer(cols = c(Shannon_tp1, Shannon_tp2),
            names_to = "Timepoint", 
            values_to = "Shannon") |>
    mutate(Timepoint = as.factor(ifelse(Timepoint == "Shannon_tp1", "tp1", "tp2")))

names(df_shan_long)[2] <- "Group"
#df_shan_long$Group_tp2 <- df_shan_long$Group_tp2 == "Group"

dim(df_shan_long)
head(df_shan_long)
# Out:
# [1] 64  5
#   Personal_number Group       delta      Timepoint Shannon
# 1 P159f9c8        Nulliparous  0.6345740 tp1       0.13195913
# 2 P159f9c8        Nulliparous  0.6345740 tp2       0.76653316
# 3 P1f95844        Nulliparous -0.7660916 tp1       0.79838981
# 4 P1f95844        Nulliparous -0.7660916 tp2       0.03229818
# 5 P3cac7b0        Nulliparous  0.5752551 tp1       0.08743932
# 6 P3cac7b0        Nulliparous  0.5752551 tp2       0.66269445

# %%
# Check that pn are correct
df_shan_long |> filter(Personal_number == "P159f9c8")
# Out:
#   Personal_number Group       delta      Timepoint Shannon
# 1 P159f9c8        Nulliparous  0.6345740 tp1       0.13195913
# 2 P159f9c8        Nulliparous  0.6345740 tp2       0.76653316
# 3 P159f9c8        Primiparous -0.6418283 tp1       0.71135388
# 4 P159f9c8        Primiparous -0.6418283 tp2       0.06952553

# %%
df_shan_long$Group <- as.factor(df_shan_long$Group)
class(df_shan_long$Group)
# Out:
# [1] "factor"

# %%
#help(geom_violinhalf)
df_shan_long |> filter (Group == "Nulliparous") |> filter(Timepoint == "tp1")
# Out:
#    Personal_number Group       delta       Timepoint Shannon
# 1  P159f9c8        Nulliparous  0.63457403 tp1       0.13195913
# 2  P1f95844        Nulliparous -0.76609163 tp1       0.79838981
# 3  P3cac7b0        Nulliparous  0.57525513 tp1       0.08743932
# 4  P3db7da6        Nulliparous  0.15255566 tp1       0.00411877
# 5  P424fd61        Nulliparous -0.30657974 tp1       0.78158728
# 6  P4de45e7        Nulliparous -0.39465378 tp1       0.57158167
# 7  P5b98b6c        Nulliparous  0.13689709 tp1       1.21265624
# 8  P62ea0b2        Nulliparous  0.85196480 tp1       0.02248438
# 9  P719b21e        Nulliparous  0.02666636 tp1       1.17077006
# 10 P7ece52e        Nulliparous  0.32657988 tp1       1.49272709
# 11 P97574f9        Nulliparous  0.01268509 tp1       0.05371978
# 12 P9cdfd5a        Nulliparous -1.47688571 tp1       1.61873560
# 13 Pbe289c8        Nulliparous -0.03649240 tp1       0.07102710
# 14 Pc77a35c        Nulliparous  0.15848732 tp1       0.74256071
# 15 Pca94a0f        Nulliparous  1.05540084 tp1       0.20949686
# 16 Pdab1897        Nulliparous -0.62109188 tp1       0.64242426

# %%
dye <- c("Nulliparous" = "darkgoldenrod3", "Primiparous" = "turquoise4")

plot_shannon <- df_shan_long |> 
    ggplot(aes(x = Timepoint, y = Shannon, fill = Group)) +
    geom_boxplot(width = 0.15) +
    #geom_rain()+
# Handles tp1 half
    geom_violinhalf(alpha = 0.5, flip = c(1,2), data = df_shan_long |>
                    filter(Timepoint == "tp1"), position = position_nudge(-0.1)
                   ) +
# Handles tp2 half
   geom_violinhalf(alpha = 0.5, flip = c(3,4), data = df_shan_long |>
                    filter(Timepoint == "tp2"), position = position_nudge(0.1)
                   ) +
# Ensures that only points of the same personal# and Group are connected 
    geom_line(
        data = df_shan_long |> 
        group_by(Personal_number, Group, Timepoint) |> 
        ungroup(),
        mapping = aes(
        x = ifelse(Timepoint == "tp1", 1.15, 1.85), # Ofset since the geom_jitter is nudged
        y = Shannon,
        group = interaction(Personal_number, Group),
        color = Group
        ),
      alpha = 0.5,
      linewidth = 0.5
            ) +
    geom_jitter(data = df_shan_long |>
                    filter(Timepoint == "tp1"), position = position_nudge(0.15), shape = 21, alpha = 0.6, size = 2) +
    geom_jitter(data = df_shan_long |>
                    filter(Timepoint == "tp2"), position = position_nudge(-0.15), shape = 21, alpha = 0.6, size = 2) +
    scale_fill_manual(values = dye) +
    scale_colour_manual(values = dye) +
       annotate("text", x = Inf, y = Inf, label="p-value = ns", hjust = -0.15, vjust = 20, size = 4.5) +

# Prevents ggplot from cutting of elements outside plot area
    coord_cartesian(clip = "off") +
    theme_half_open() +
theme(
        legend.box.background = element_rect(color = "Black", size = 0.5),
        legend.box.margin = margin(4, 4, 4, 4),
        legend.title = element_text(face = "bold", size = 15),
        title = element_text(size = 18),
        axis.title.y = element_text(size = 15, face = "bold"),
        axis.title.x = element_text(size = 15, face = "bold"),
        panel.grid.major = element_line(colour = "lightgrey"),
        panel.grid.minor = element_line(colour = "lightgrey")
    )
plot_shannon
# Out:
# plot without title

# %% [markdown]
# ### Significance-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [raw]
# # Next a wide table is needed where each row is one personal# --> meaning the delta for each pregnancy (nulliparous & primiparous) has it's own column
# Since the delta is duplicated for the timepoints (tp2- tp1) I only need to pick rows with tp2

# %%
# Select variables of interest
shan_wide_delta <- df_shan_long |> filter(Timepoint == "tp2") |> 
    select(Personal_number, Group, delta) |> 
    pivot_wider(
    names_from = Group,
    values_from = delta)
    
head(shan_wide_delta)
# Out:
#   Personal_number Nulliparous Primiparous
# 1 P159f9c8         0.6345740  -0.64182835
# 2 P1f95844        -0.7660916   1.31394618
# 3 P3cac7b0         0.5752551  -0.28243979
# 4 P3db7da6         0.1525557   0.10286336
# 5 P424fd61        -0.3065797  -0.92598667
# 6 P4de45e7        -0.3946538   0.03039534

# %%
shan_wide_delta <- shan_wide_delta |> rename(Nulliparous_delta = Nulliparous)
shan_wide_delta <- shan_wide_delta |> rename(Primiparous_delta = Primiparous)
head(shan_wide_delta)
dim(shan_wide_delta)
# Out:
#   Personal_number Nulliparous_delta Primiparous_delta
# 1 P159f9c8         0.6345740        -0.64182835
# 2 P1f95844        -0.7660916         1.31394618
# 3 P3cac7b0         0.5752551        -0.28243979
# 4 P3db7da6         0.1525557         0.10286336
# 5 P424fd61        -0.3065797        -0.92598667
# 6 P4de45e7        -0.3946538         0.03039534
# [1] 16  3

# %% [raw]
# Now each column contains the delta shannon for tp2-tp1 for respective groups

# %%
shan_wide_delta$difference <- shan_wide_delta$Primiparous_delta - shan_wide_delta$Nulliparous_delta
shapiro.test(shan_wide_delta$difference)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  shan_wide_delta$difference
# W = 0.93399, p-value = 0.2818

# %% [raw]
# # Data is Normaly distributed

# %%
# Plot distribution
shan_wide_delta |> ggplot(aes(x = difference)) +
    geom_histogram( binwidth = 0.2, position = "identity", fill = "slateblue", col = "black") +
    labs(
    title = "Histogram of delta Shannon Index difference",
    x = "Difference",
    y = "Frequency"
  ) + 
  scale_y_continuous(
    # Don't expand y scale at the lower end
    expand = expansion(mult = c(0, 0.05))
  ) +
  theme_half_open()
# Out:
# plot without title

# %%
t.test(Pair(Nulliparous_delta, Primiparous_delta) ~ 1,data = shan_wide_delta)
# Out:
# 	Paired t-test
#
# data:  Pair(Nulliparous_delta, Primiparous_delta)
# t = 0.1707, df = 15, p-value = 0.8667
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  -0.4066585  0.4774664
# sample estimates:
# mean difference
#      0.03540395

# %% [markdown]
# ## Richness------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### First pregnancy

# %%
tp1_richness_combined$Group <- as.factor(tp1_richness_combined$Group)
head(tp1_richness_combined)
tp2_richness_combined$Group <- as.factor(tp2_richness_combined$Group)
head(tp2_richness_combined)
# Out:
#   Sample_ID  Species_richness Group       Personal_number
# 1 FF00653546 29               Nulliparous P159f9c8
# 2 FB02825409 24               Nulliparous P1f862a6
# 3 FF02015345 17               Nulliparous P1f95844
# 4 FF00653065  8               Nulliparous P3cac7b0
# 5 FF02014263  3               Nulliparous P3db7da6
# 6 FF02015432 37               Nulliparous P424fd61
#   Sample_ID  Species_richness Group       Personal_number
# 1 FF02740612 16               Nulliparous P159f9c8
# 2 FF02014450 15               Nulliparous P1f95844
# 3 FF02014344 11               Nulliparous P3cac7b0
# 4 FF03816858  6               Nulliparous P3db7da6
# 5 FF02557245  5               Nulliparous P424fd61
# 6 FF02015423 11               Nulliparous P4de45e7

# %%
# Create a df for Fp tp1
richness_fp_tp1 <- tp1_richness_combined |> filter(Group == "Nulliparous")
head(richness_fp_tp1)
dim(richness_fp_tp1)
# Out:
#   Sample_ID  Species_richness Group       Personal_number
# 1 FF00653546 29               Nulliparous P159f9c8
# 2 FB02825409 24               Nulliparous P1f862a6
# 3 FF02015345 17               Nulliparous P1f95844
# 4 FF00653065  8               Nulliparous P3cac7b0
# 5 FF02014263  3               Nulliparous P3db7da6
# 6 FF02015432 37               Nulliparous P424fd61
# [1] 26  4

# %%
# Sanity check
unique(richness_fp_tp1$Group)
table(richness_fp_tp1$Group)
# Out:
# [1] Nulliparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#          26           0

# %%
# Create df for Fp tp2
richness_fp_tp2 <- tp2_richness_combined |>
    filter(Group == "Nulliparous")
dim(richness_fp_tp2)
head(richness_fp_tp2)
# Out:
# [1] 16  4
#   Sample_ID  Species_richness Group       Personal_number
# 1 FF02740612 16               Nulliparous P159f9c8
# 2 FF02014450 15               Nulliparous P1f95844
# 3 FF02014344 11               Nulliparous P3cac7b0
# 4 FF03816858  6               Nulliparous P3db7da6
# 5 FF02557245  5               Nulliparous P424fd61
# 6 FF02015423 11               Nulliparous P4de45e7

# %%
# Sanity check
unique(richness_fp_tp2$Group)
table(richness_fp_tp2$Group)
# Out:
# [1] Nulliparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#          16           0

# %%
# Merge df by Personal num & add sufixes to colnmes
richness_merged_fp <- merge(richness_fp_tp1, richness_fp_tp2, by= "Personal_number", suffixes = c("_tp1", "_tp2"))
dim(richness_merged_fp)
head(richness_merged_fp)
# Out:
# [1] 16  7
#   Personal_number Sample_ID_tp1 Species_richness_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF00653546    29                   Nulliparous FF02740612
# 2 P1f95844        FF02015345    17                   Nulliparous FF02014450
# 3 P3cac7b0        FF00653065     8                   Nulliparous FF02014344
# 4 P3db7da6        FF02014263     3                   Nulliparous FF03816858
# 5 P424fd61        FF02015432    37                   Nulliparous FF02557245
# 6 P4de45e7        FF00653167     6                   Nulliparous FF02015423
#   Species_richness_tp2 Group_tp2
# 1 16                   Nulliparous
# 2 15                   Nulliparous
# 3 11                   Nulliparous
# 4  6                   Nulliparous
# 5  5                   Nulliparous
# 6 11                   Nulliparous

# %%
# Do calculation
richness_merged_fp$delta <- richness_merged_fp$Species_richness_tp2 - richness_merged_fp$Species_richness_tp1
head(richness_merged_fp)
# Out:
#   Personal_number Sample_ID_tp1 Species_richness_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF00653546    29                   Nulliparous FF02740612
# 2 P1f95844        FF02015345    17                   Nulliparous FF02014450
# 3 P3cac7b0        FF00653065     8                   Nulliparous FF02014344
# 4 P3db7da6        FF02014263     3                   Nulliparous FF03816858
# 5 P424fd61        FF02015432    37                   Nulliparous FF02557245
# 6 P4de45e7        FF00653167     6                   Nulliparous FF02015423
#   Species_richness_tp2 Group_tp2   delta
# 1 16                   Nulliparous -13
# 2 15                   Nulliparous  -2
# 3 11                   Nulliparous   3
# 4  6                   Nulliparous   3
# 5  5                   Nulliparous -32
# 6 11                   Nulliparous   5

# %% [markdown]
# ### Second pregnancy

# %%
# Create a df for Sp tp1
richness_sp_tp1 <- tp1_richness_combined |> filter(Group == "Primiparous")
head(richness_sp_tp1)
dim(richness_sp_tp1)
# Out:
#   Sample_ID  Species_richness Group       Personal_number
# 1 FF01566745 10               Primiparous P159f9c8
# 2 FF06039085  9               Primiparous P1f862a6
# 3 FF06039601  4               Primiparous P1f95844
# 4 FF06039627 16               Primiparous P3cac7b0
# 5 FF03817982 10               Primiparous P3db7da6
# 6 FF05044855 25               Primiparous P424fd61
# [1] 26  4

# %%
# Sanity check
unique(richness_sp_tp1$Group)
table(richness_sp_tp1$Group)
# Out:
# [1] Primiparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#           0          26

# %%
# Create a df for Sp tp2
richness_sp_tp2 <- tp2_richness_combined |> filter(Group == "Primiparous")
head(richness_sp_tp2)
dim(richness_sp_tp2)
# Out:
#   Sample_ID  Species_richness Group       Personal_number
# 1 FF08440357 11               Primiparous P159f9c8
# 2 FF04761496 19               Primiparous P1f95844
# 3 FF08440702 22               Primiparous P3cac7b0
# 4 FF05024823  6               Primiparous P3db7da6
# 5 FF06580149  6               Primiparous P424fd61
# 6 FF01572330  7               Primiparous P4de45e7
# [1] 16  4

# %%
# Sanity check
unique(richness_sp_tp2$Group)
table(richness_sp_tp2$Group)
# Out:
# [1] Primiparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#           0          16

# %% [markdown]
# ### Plot------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Merge df by Personal num & add sufixes to colnmes
richness_merged_sp <- merge(richness_sp_tp1, richness_sp_tp2, by= "Personal_number", suffixes = c("_tp1", "_tp2"))
dim(richness_merged_sp)
head(richness_merged_sp)
# Out:
# [1] 16  7
#   Personal_number Sample_ID_tp1 Species_richness_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF01566745    10                   Primiparous FF08440357
# 2 P1f95844        FF06039601     4                   Primiparous FF04761496
# 3 P3cac7b0        FF06039627    16                   Primiparous FF08440702
# 4 P3db7da6        FF03817982    10                   Primiparous FF05024823
# 5 P424fd61        FF05044855    25                   Primiparous FF06580149
# 6 P4de45e7        FF06040007     9                   Primiparous FF01572330
#   Species_richness_tp2 Group_tp2
# 1 11                   Primiparous
# 2 19                   Primiparous
# 3 22                   Primiparous
# 4  6                   Primiparous
# 5  6                   Primiparous
# 6  7                   Primiparous

# %%
# Do calulations
richness_merged_sp$delta <- richness_merged_sp$Species_richness_tp2 - richness_merged_sp$Species_richness_tp1
head(richness_merged_sp)
# Out:
#   Personal_number Sample_ID_tp1 Species_richness_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF01566745    10                   Primiparous FF08440357
# 2 P1f95844        FF06039601     4                   Primiparous FF04761496
# 3 P3cac7b0        FF06039627    16                   Primiparous FF08440702
# 4 P3db7da6        FF03817982    10                   Primiparous FF05024823
# 5 P424fd61        FF05044855    25                   Primiparous FF06580149
# 6 P4de45e7        FF06040007     9                   Primiparous FF01572330
#   Species_richness_tp2 Group_tp2   delta
# 1 11                   Primiparous   1
# 2 19                   Primiparous  15
# 3 22                   Primiparous   6
# 4  6                   Primiparous  -4
# 5  6                   Primiparous -19
# 6  7                   Primiparous  -2

# %%
richness_combined_df <- rbind(richness_merged_fp, richness_merged_sp)
head(richness_combined_df)
# Out:
#   Personal_number Sample_ID_tp1 Species_richness_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF00653546    29                   Nulliparous FF02740612
# 2 P1f95844        FF02015345    17                   Nulliparous FF02014450
# 3 P3cac7b0        FF00653065     8                   Nulliparous FF02014344
# 4 P3db7da6        FF02014263     3                   Nulliparous FF03816858
# 5 P424fd61        FF02015432    37                   Nulliparous FF02557245
# 6 P4de45e7        FF00653167     6                   Nulliparous FF02015423
#   Species_richness_tp2 Group_tp2   delta
# 1 16                   Nulliparous -13
# 2 15                   Nulliparous  -2
# 3 11                   Nulliparous   3
# 4  6                   Nulliparous   3
# 5  5                   Nulliparous -32
# 6 11                   Nulliparous   5

# %%
# Reshape df into long format for easier plotting

df_richness_long <- richness_combined_df |>
    select(Personal_number, Species_richness_tp1, Species_richness_tp2, Group_tp2, delta) |>
pivot_longer(cols = c(Species_richness_tp1, Species_richness_tp2),
            names_to = "Timepoint", 
            values_to = "Richness") |>
    mutate(Timepoint = as.factor(ifelse(Timepoint == "Species_richness_tp1", "tp1", "tp2")))

names(df_richness_long)[2] <- "Group"

dim(df_richness_long)
head(df_richness_long)
# Out:
# [1] 64  5
#   Personal_number Group       delta Timepoint Richness
# 1 P159f9c8        Nulliparous -13   tp1       29
# 2 P159f9c8        Nulliparous -13   tp2       16
# 3 P1f95844        Nulliparous  -2   tp1       17
# 4 P1f95844        Nulliparous  -2   tp2       15
# 5 P3cac7b0        Nulliparous   3   tp1        8
# 6 P3cac7b0        Nulliparous   3   tp2       11

# %%
# Check that pn are correct
df_richness_long |> filter(Personal_number == "P159f9c8")
# Out:
#   Personal_number Group       delta Timepoint Richness
# 1 P159f9c8        Nulliparous -13   tp1       29
# 2 P159f9c8        Nulliparous -13   tp2       16
# 3 P159f9c8        Primiparous   1   tp1       10
# 4 P159f9c8        Primiparous   1   tp2       11

# %%
plot_richness <- df_richness_long |> 
    ggplot(aes(x = Timepoint, y = Richness, fill = Group)) +
    geom_boxplot(width = 0.15) +
    #geom_rain()+
# Handles tp1 half
    geom_violinhalf(alpha = 0.5, flip = c(1,2), data = df_richness_long |>
                    filter(Timepoint == "tp1"), position = position_nudge(-0.1)
                   ) +
# Handles tp2 half
   geom_violinhalf(alpha = 0.5, flip = c(3,4), data = df_richness_long |>
                    filter(Timepoint == "tp2"), position = position_nudge(0.1)
                   ) +
# Ensures that only points of the same personal# and Group are connected 
    geom_line(
        data = df_richness_long |> 
        group_by(Personal_number, Group, Timepoint) |> 
        ungroup(),
        mapping = aes(
        x = ifelse(Timepoint == "tp1", 1.15, 1.85), # Ofset since the geom_jitter is nudged
        y = Richness,
        group = interaction(Personal_number, Group),
        color = Group
        ),
      alpha = 0.5,
      linewidth = 0.5
            ) +
    geom_jitter(data = df_richness_long |>
                    filter(Timepoint == "tp1"), position = position_nudge(0.15), shape = 21, alpha = 0.6, size = 2) +
    geom_jitter(data = df_richness_long |>
                    filter(Timepoint == "tp2"), position = position_nudge(-0.15), shape = 21, alpha = 0.6, size = 2) +
    scale_fill_manual(values = dye) +
    scale_colour_manual(values = dye) +
        annotate("text", x = Inf, y = Inf, label="p-value = ns", hjust = -0.15, vjust = 20, size = 4.5) +
# Prevents ggplot from cutting of elements outside plot area
    coord_cartesian(clip = "off") +
    theme_half_open() +
theme(
        legend.box.background = element_rect(color = "Black", size = 0.5),
        legend.box.margin = margin(4, 4, 4, 4),
        legend.title = element_text(face = "bold", size = 15),
        title = element_text(size = 18),
        axis.title.y = element_text(size = 15, face = "bold"),
        axis.title.x = element_text(size = 15, face = "bold"),
        panel.grid.major = element_line(colour = "lightgrey"),
        panel.grid.minor = element_line(colour = "lightgrey")
    )
plot_richness
# Out:
# plot without title

# %% [markdown]
# ### Significance------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Create a wide table
# Select variables of interest
rich_wide_delta <- df_richness_long |> filter(Timepoint == "tp2") |> 
    select(Personal_number, Group, delta) |> 
    pivot_wider(
    names_from = Group,
    values_from = delta)
    
head(rich_wide_delta)
# Out:
#   Personal_number Nulliparous Primiparous
# 1 P159f9c8        -13           1
# 2 P1f95844         -2          15
# 3 P3cac7b0          3           6
# 4 P3db7da6          3          -4
# 5 P424fd61        -32         -19
# 6 P4de45e7          5          -2

# %%
rich_wide_delta <- rich_wide_delta |> rename(Nulliparous_delta = Nulliparous)
rich_wide_delta <- rich_wide_delta |> rename(Primiparous_delta = Primiparous)
head(rich_wide_delta)
dim(rich_wide_delta)
# Out:
#   Personal_number Nulliparous_delta Primiparous_delta
# 1 P159f9c8        -13                 1
# 2 P1f95844         -2                15
# 3 P3cac7b0          3                 6
# 4 P3db7da6          3                -4
# 5 P424fd61        -32               -19
# 6 P4de45e7          5                -2
# [1] 16  3

# %%
rich_wide_delta$difference <- rich_wide_delta$Primiparous_delta - rich_wide_delta$Nulliparous_delta
shapiro.test(rich_wide_delta$difference)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  rich_wide_delta$difference
# W = 0.92064, p-value = 0.1727

# %% [raw]
# # p-val greater than 0.05 so data is normaly distributed

# %%
# Plot distribution
rich_wide_delta |> ggplot(aes(x = difference)) +
    geom_histogram( binwidth = 3, position = "identity", fill = "slateblue", col = "black") +
    labs(
    title = "Histogram of delta Richness difference",
    x = "Difference",
    y = "Frequency"
  ) + 
  scale_y_continuous(
    # Don't expand y scale at the lower end
    expand = expansion(mult = c(0, 0.05))
  ) +
  theme_half_open()
# Out:
# plot without title

# %% [raw]
# # t-test

# %%
t.test(Pair(Nulliparous_delta, Primiparous_delta) ~ 1,data = rich_wide_delta)
# Out:
# 	Paired t-test
#
# data:  Pair(Nulliparous_delta, Primiparous_delta)
# t = -1.9315, df = 15, p-value = 0.07254
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  -12.6212306   0.6212306
# sample estimates:
# mean difference
#              -6

# %% [markdown]
# ## Species Evenness---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### First pregnancy

# %%
tp1_evenness_combined$Group <- as.factor(tp1_evenness_combined$Group)
head(tp1_evenness_combined)
tp2_evenness_combined$Group <- as.factor(tp2_evenness_combined$Group)
head(tp2_evenness_combined)
# Out:
#   Sample_ID  Evenness    Group       Personal_number
# 1 FF00653546 0.039188457 Nulliparous P159f9c8
# 2 FB02825409 0.407456387 Nulliparous P1f862a6
# 3 FF02015345 0.281796573 Nulliparous P1f95844
# 4 FF00653065 0.042049425 Nulliparous P3cac7b0
# 5 FF02014263 0.003749066 Nulliparous P3db7da6
# 6 FF02015432 0.216451135 Nulliparous P424fd61
#   Sample_ID  Evenness   Group       Personal_number
# 1 FF02740612 0.27646840 Nulliparous P159f9c8
# 2 FF02014450 0.01192673 Nulliparous P1f95844
# 3 FF02014344 0.27636505 Nulliparous P3cac7b0
# 4 FF03816858 0.08744167 Nulliparous P3db7da6
# 5 FF02557245 0.29513878 Nulliparous P424fd61
# 6 FF02015423 0.07378466 Nulliparous P4de45e7

# %%
# Create a df with just fp tp1
# Create a df for fp tp1
evenness_fp_tp1 <- tp1_evenness_combined |> filter(Group == "Nulliparous")
head(evenness_fp_tp1)
dim(evenness_fp_tp1)
# Out:
#   Sample_ID  Evenness    Group       Personal_number
# 1 FF00653546 0.039188457 Nulliparous P159f9c8
# 2 FB02825409 0.407456387 Nulliparous P1f862a6
# 3 FF02015345 0.281796573 Nulliparous P1f95844
# 4 FF00653065 0.042049425 Nulliparous P3cac7b0
# 5 FF02014263 0.003749066 Nulliparous P3db7da6
# 6 FF02015432 0.216451135 Nulliparous P424fd61
# [1] 26  4

# %%
# Sanity check
unique(evenness_fp_tp1$Group)
table(evenness_fp_tp1$Group)
# Out:
# [1] Nulliparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#          26           0

# %%
# Create a df with just fp tp2
# Create a df for fp tp1
evenness_fp_tp2 <- tp2_evenness_combined |> filter(Group == "Nulliparous")
head(evenness_fp_tp2)
dim(evenness_fp_tp2)
# Out:
#   Sample_ID  Evenness   Group       Personal_number
# 1 FF02740612 0.27646840 Nulliparous P159f9c8
# 2 FF02014450 0.01192673 Nulliparous P1f95844
# 3 FF02014344 0.27636505 Nulliparous P3cac7b0
# 4 FF03816858 0.08744167 Nulliparous P3db7da6
# 5 FF02557245 0.29513878 Nulliparous P424fd61
# 6 FF02015423 0.07378466 Nulliparous P4de45e7
# [1] 16  4

# %%
unique(evenness_fp_tp2$Group)
table(evenness_fp_tp2$Group)
# Out:
# [1] Nulliparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#          16           0

# %%
# Merge df by Personal num & add sufixes to colnmes
evenness_merged_fp <- merge(evenness_fp_tp2, evenness_fp_tp1, by = "Personal_number", suffixes = c("_tp1", "_tp2"))
dim(evenness_merged_fp)
head(evenness_merged_fp)
# Out:
# [1] 16  7
#   Personal_number Sample_ID_tp1 Evenness_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF02740612    0.27646840   Nulliparous FF00653546
# 2 P1f95844        FF02014450    0.01192673   Nulliparous FF02015345
# 3 P3cac7b0        FF02014344    0.27636505   Nulliparous FF00653065
# 4 P3db7da6        FF03816858    0.08744167   Nulliparous FF02014263
# 5 P424fd61        FF02557245    0.29513878   Nulliparous FF02015432
# 6 P4de45e7        FF02015423    0.07378466   Nulliparous FF00653167
#   Evenness_tp2 Group_tp2
# 1 0.039188457  Nulliparous
# 2 0.281796573  Nulliparous
# 3 0.042049425  Nulliparous
# 4 0.003749066  Nulliparous
# 5 0.216451135  Nulliparous
# 6 0.319005803  Nulliparous

# %%
# Do calculation
evenness_merged_fp$delta <- evenness_merged_fp$Evenness_tp2 - evenness_merged_fp$Evenness_tp1
head(evenness_merged_fp)
# Out:
#   Personal_number Sample_ID_tp1 Evenness_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF02740612    0.27646840   Nulliparous FF00653546
# 2 P1f95844        FF02014450    0.01192673   Nulliparous FF02015345
# 3 P3cac7b0        FF02014344    0.27636505   Nulliparous FF00653065
# 4 P3db7da6        FF03816858    0.08744167   Nulliparous FF02014263
# 5 P424fd61        FF02557245    0.29513878   Nulliparous FF02015432
# 6 P4de45e7        FF02015423    0.07378466   Nulliparous FF00653167
#   Evenness_tp2 Group_tp2   delta
# 1 0.039188457  Nulliparous -0.23727994
# 2 0.281796573  Nulliparous  0.26986984
# 3 0.042049425  Nulliparous -0.23431563
# 4 0.003749066  Nulliparous -0.08369260
# 5 0.216451135  Nulliparous -0.07868764
# 6 0.319005803  Nulliparous  0.24522114

# %% [markdown]
# ### Second Pregnancy

# %%
# Create a df with sp tp1
evenness_sp_tp1 <- tp1_evenness_combined |> filter(Group == "Primiparous")
head(evenness_sp_tp1)
dim(evenness_sp_tp1)
# Out:
#   Sample_ID  Evenness    Group       Personal_number
# 1 FF01566745 0.308937064 Primiparous P159f9c8
# 2 FF06039085 0.009140144 Primiparous P1f862a6
# 3 FF06039601 0.003465086 Primiparous P1f95844
# 4 FF06039627 0.366860413 Primiparous P3cac7b0
# 5 FF03817982 0.257818219 Primiparous P3db7da6
# 6 FF05044855 0.340767362 Primiparous P424fd61
# [1] 26  4

# %%
unique(evenness_sp_tp1$Group)
table(evenness_sp_tp1$Group)
# Out:
# [1] Primiparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#           0          26

# %%
# Create a df with sp tp1
evenness_sp_tp2 <- tp2_evenness_combined |> filter(Group == "Primiparous")
head(evenness_sp_tp2)
dim(evenness_sp_tp2)
# Out:
#   Sample_ID  Evenness   Group       Personal_number
# 1 FF08440357 0.02899440 Primiparous P159f9c8
# 2 FF04761496 0.44787812 Primiparous P1f95844
# 3 FF08440702 0.23769109 Primiparous P3cac7b0
# 4 FF05024823 0.38873061 Primiparous P3db7da6
# 5 FF06580149 0.09538175 Primiparous P424fd61
# 6 FF01572330 0.35626829 Primiparous P4de45e7
# [1] 16  4

# %%
unique(evenness_sp_tp2$Group)
table(evenness_sp_tp2$Group)
# Out:
# [1] Primiparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#           0          16

# %%
# Merge df by Personal num & add sufixes to colnmes
evenness_merged_sp <- merge(evenness_sp_tp2, evenness_sp_tp1, by= "Personal_number", suffixes = c("_tp1", "_tp2"))
dim(evenness_merged_sp)
head(evenness_merged_sp)
# Out:
# [1] 16  7
#   Personal_number Sample_ID_tp1 Evenness_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF08440357    0.02899440   Primiparous FF01566745
# 2 P1f95844        FF04761496    0.44787812   Primiparous FF06039601
# 3 P3cac7b0        FF08440702    0.23769109   Primiparous FF06039627
# 4 P3db7da6        FF05024823    0.38873061   Primiparous FF03817982
# 5 P424fd61        FF06580149    0.09538175   Primiparous FF05044855
# 6 P4de45e7        FF01572330    0.35626829   Primiparous FF06040007
#   Evenness_tp2 Group_tp2
# 1 0.308937064  Primiparous
# 2 0.003465086  Primiparous
# 3 0.366860413  Primiparous
# 4 0.257818219  Primiparous
# 5 0.340767362  Primiparous
# 6 0.301685471  Primiparous

# %%
# Do calulations for Sp
evenness_merged_sp$delta <- evenness_merged_sp$Evenness_tp2 - evenness_merged_sp$Evenness_tp1
head(evenness_merged_sp)
# Out:
#   Personal_number Sample_ID_tp1 Evenness_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF08440357    0.02899440   Primiparous FF01566745
# 2 P1f95844        FF04761496    0.44787812   Primiparous FF06039601
# 3 P3cac7b0        FF08440702    0.23769109   Primiparous FF06039627
# 4 P3db7da6        FF05024823    0.38873061   Primiparous FF03817982
# 5 P424fd61        FF06580149    0.09538175   Primiparous FF05044855
# 6 P4de45e7        FF01572330    0.35626829   Primiparous FF06040007
#   Evenness_tp2 Group_tp2   delta
# 1 0.308937064  Primiparous  0.27994267
# 2 0.003465086  Primiparous -0.44441304
# 3 0.366860413  Primiparous  0.12916932
# 4 0.257818219  Primiparous -0.13091239
# 5 0.340767362  Primiparous  0.24538561
# 6 0.301685471  Primiparous -0.05458281

# %% [markdown]
# ### Plot------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
evenness_combined_df <- rbind(evenness_merged_fp, evenness_merged_sp)
head(evenness_combined_df)
# Out:
#   Personal_number Sample_ID_tp1 Evenness_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF02740612    0.27646840   Nulliparous FF00653546
# 2 P1f95844        FF02014450    0.01192673   Nulliparous FF02015345
# 3 P3cac7b0        FF02014344    0.27636505   Nulliparous FF00653065
# 4 P3db7da6        FF03816858    0.08744167   Nulliparous FF02014263
# 5 P424fd61        FF02557245    0.29513878   Nulliparous FF02015432
# 6 P4de45e7        FF02015423    0.07378466   Nulliparous FF00653167
#   Evenness_tp2 Group_tp2   delta
# 1 0.039188457  Nulliparous -0.23727994
# 2 0.281796573  Nulliparous  0.26986984
# 3 0.042049425  Nulliparous -0.23431563
# 4 0.003749066  Nulliparous -0.08369260
# 5 0.216451135  Nulliparous -0.07868764
# 6 0.319005803  Nulliparous  0.24522114

# %%
# Reshape df into long format for easier plotting

df_evenness_long <- evenness_combined_df |>
    select(Personal_number, Evenness_tp1, Evenness_tp2, Group_tp2, delta) |>
pivot_longer(cols = c(Evenness_tp1, Evenness_tp2),
            names_to = "Timepoint", 
            values_to = "Evenness") |>
    mutate(Timepoint = as.factor(ifelse(Timepoint == "Evenness_tp1", "tp1", "tp2")))

names(df_evenness_long)[2] <- "Group"

dim(df_evenness_long)
head(df_evenness_long)
# Out:
# [1] 64  5
#   Personal_number Group       delta      Timepoint Evenness
# 1 P159f9c8        Nulliparous -0.2372799 tp1       0.27646840
# 2 P159f9c8        Nulliparous -0.2372799 tp2       0.03918846
# 3 P1f95844        Nulliparous  0.2698698 tp1       0.01192673
# 4 P1f95844        Nulliparous  0.2698698 tp2       0.28179657
# 5 P3cac7b0        Nulliparous -0.2343156 tp1       0.27636505
# 6 P3cac7b0        Nulliparous -0.2343156 tp2       0.04204943

# %%
# Check that pn are correct
df_evenness_long |> filter(Personal_number == "P1a267fa")
# Out:
#      Personal_number Group delta Timepoint Evenness

# %%
plot_evenness <- df_evenness_long |> 
    ggplot(aes(x = Timepoint, y = Evenness, fill = Group)) +
    geom_boxplot(width = 0.15) +
    #geom_rain()+
# Handles tp1 half
    geom_violinhalf(alpha = 0.5, flip = c(1,2), data = df_evenness_long |>
                    filter(Timepoint == "tp1"), position = position_nudge(-0.1)
                   ) +
# Handles tp2 half
   geom_violinhalf(alpha = 0.5, flip = c(3,4), data = df_evenness_long |>
                    filter(Timepoint == "tp2"), position = position_nudge(0.1)
                   ) +
# Ensures that only points of the same personal# and Group are connected 
    geom_line(
        data = df_evenness_long |> 
        group_by(Personal_number, Group, Timepoint) |> 
        ungroup(),
        mapping = aes(
        x = ifelse(Timepoint == "tp1", 1.15, 1.85), # Ofset since the geom_jitter is nudged
        y = Evenness,
        group = interaction(Personal_number, Group),
        color = Group
        ),
      alpha = 0.5,
      linewidth = 0.5
            ) +
    geom_jitter(data = df_evenness_long |>
                    filter(Timepoint == "tp1"), position = position_nudge(0.15), shape = 21, alpha = 0.6, size = 2) +
    geom_jitter(data = df_evenness_long |>
                    filter(Timepoint == "tp2"), position = position_nudge(-0.15), shape = 21, alpha = 0.6, size = 2) +
    labs(
        title = "Rain plot of Evenness"
    ) +
    scale_fill_manual(values = dye) +
    scale_colour_manual(values = dye)+
    theme_half_open() +
    annotate("text", x = Inf, y = Inf, label="p-value = ns", hjust = -0.15, vjust = 20, size = 4.5) +

# Prevents ggplot from cutting of elements outside plot area
    coord_cartesian(clip = "off") +
    theme(
        legend.box.background = element_rect(color = "Black", size = 0.5),
        legend.box.margin = margin(4, 4, 4, 4),
        legend.title = element_text(face = "bold", size = 15),
        title = element_text(size = 18),
        axis.title.y = element_text(size = 15, face = "bold"),
        axis.title.x = element_text(size = 15, face = "bold"),
        panel.grid.major = element_line(colour = "lightgrey"),
        panel.grid.minor = element_line(colour = "lightgrey")
    )
plot_evenness
# Out:
# plot without title

# %% [markdown]
# ### Significance----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Create a wide table
# Select variables of interest
even_wide_delta <- df_evenness_long |> filter(Timepoint == "tp2") |> 
    select(Personal_number, Group, delta) |> 
    pivot_wider(
    names_from = Group,
    values_from = delta)
    
head(even_wide_delta)
# Out:
#   Personal_number Nulliparous Primiparous
# 1 P159f9c8        -0.23727994  0.27994267
# 2 P1f95844         0.26986984 -0.44441304
# 3 P3cac7b0        -0.23431563  0.12916932
# 4 P3db7da6        -0.08369260 -0.13091239
# 5 P424fd61        -0.07868764  0.24538561
# 6 P4de45e7         0.24522114 -0.05458281

# %%
even_wide_delta <- even_wide_delta |> rename(Nulliparous_delta = Nulliparous)
even_wide_delta <- even_wide_delta |> rename(Primiparous_delta = Primiparous)
head(even_wide_delta)
dim(even_wide_delta)
# Out:
#   Personal_number Nulliparous_delta Primiparous_delta
# 1 P159f9c8        -0.23727994        0.27994267
# 2 P1f95844         0.26986984       -0.44441304
# 3 P3cac7b0        -0.23431563        0.12916932
# 4 P3db7da6        -0.08369260       -0.13091239
# 5 P424fd61        -0.07868764        0.24538561
# 6 P4de45e7         0.24522114       -0.05458281
# [1] 16  3

# %%
even_wide_delta$difference <- even_wide_delta$Primiparous_delta - even_wide_delta$Nulliparous_delta
shapiro.test(even_wide_delta$difference)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  even_wide_delta$difference
# W = 0.95294, p-value = 0.5376

# %% [raw]
# # Normaly distributed

# %%
# Plot distribution
even_wide_delta |> ggplot(aes(x = difference)) +
    geom_histogram( binwidth = 0.025, position = "identity", fill = "slateblue", col = "black") +
    labs(
    title = "Histogram of delta Evenness difference",
    x = "Difference",
    y = "Frequency"
  ) + 
  scale_y_continuous(
    # Don't expand y scale at the lower end
    expand = expansion(mult = c(0, 0.05))
  ) +
  theme_half_open()
# Out:
# plot without title

# %% [raw]
# # t.test

# %% [markdown]
# ## Simpson------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### First pregnancy

# %%
tp1_simpson_combined$Group <- as.factor(tp1_simpson_combined$Group)
head(tp1_simpson_combined)
tp2_simpson_combined$Group <- as.factor(tp2_simpson_combined$Group)
head(tp2_simpson_combined)
# Out:
#   Sample_ID  Simpson     Group       Personal_number
# 1 FF00653546 0.035194487 Nulliparous P159f9c8
# 2 FB02825409 0.547372652 Nulliparous P1f862a6
# 3 FF02015345 0.457256373 Nulliparous P1f95844
# 4 FF00653065 0.027936140 Nulliparous P3cac7b0
# 5 FF02014263 0.000877703 Nulliparous P3db7da6
# 6 FF02015432 0.264161953 Nulliparous P424fd61
#   Sample_ID  Simpson     Group       Personal_number
# 1 FF02740612 0.509929830 Nulliparous P159f9c8
# 2 FF02014450 0.007213459 Nulliparous P1f95844
# 3 FF02014344 0.407696384 Nulliparous P3cac7b0
# 4 FF03816858 0.058367645 Nulliparous P3db7da6
# 5 FF02557245 0.248208589 Nulliparous P424fd61
# 6 FF02015423 0.059153140 Nulliparous P4de45e7

# %%
# Create a df with just fp tp1
# Create a df for fp tp1
simpson_fp_tp1 <- tp1_simpson_combined |> filter(Group == "Nulliparous")
head(simpson_fp_tp1)
dim(simpson_fp_tp1)
# Out:
#   Sample_ID  Simpson     Group       Personal_number
# 1 FF00653546 0.035194487 Nulliparous P159f9c8
# 2 FB02825409 0.547372652 Nulliparous P1f862a6
# 3 FF02015345 0.457256373 Nulliparous P1f95844
# 4 FF00653065 0.027936140 Nulliparous P3cac7b0
# 5 FF02014263 0.000877703 Nulliparous P3db7da6
# 6 FF02015432 0.264161953 Nulliparous P424fd61
# [1] 26  4

# %%
# Create a df with just fp tp2
# Create a df for fp tp2
simpson_fp_tp2 <- tp2_simpson_combined |> filter(Group == "Nulliparous")
head(simpson_fp_tp2)
dim(simpson_fp_tp2)
# Out:
#   Sample_ID  Simpson     Group       Personal_number
# 1 FF02740612 0.509929830 Nulliparous P159f9c8
# 2 FF02014450 0.007213459 Nulliparous P1f95844
# 3 FF02014344 0.407696384 Nulliparous P3cac7b0
# 4 FF03816858 0.058367645 Nulliparous P3db7da6
# 5 FF02557245 0.248208589 Nulliparous P424fd61
# 6 FF02015423 0.059153140 Nulliparous P4de45e7
# [1] 16  4

# %%
# Sanity check
unique(simpson_fp_tp1$Group)
table(simpson_fp_tp1$Group)
# Out:
# [1] Nulliparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#          26           0

# %%
# Sanity check
unique(simpson_fp_tp2$Group)
table(simpson_fp_tp2$Group)
# Out:
# [1] Nulliparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#          16           0

# %%
# Merge df by Personal num & add sufixes to colnmes
simpson_merged_fp <- merge(simpson_fp_tp2, simpson_fp_tp1, by= "Personal_number", suffixes = c("_tp1", "_tp2"))
dim(simpson_merged_fp)
head(simpson_merged_fp)
# Out:
# [1] 16  7
#   Personal_number Sample_ID_tp1 Simpson_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF02740612    0.509929830 Nulliparous FF00653546
# 2 P1f95844        FF02014450    0.007213459 Nulliparous FF02015345
# 3 P3cac7b0        FF02014344    0.407696384 Nulliparous FF00653065
# 4 P3db7da6        FF03816858    0.058367645 Nulliparous FF02014263
# 5 P424fd61        FF02557245    0.248208589 Nulliparous FF02015432
# 6 P4de45e7        FF02015423    0.059153140 Nulliparous FF00653167
#   Simpson_tp2 Group_tp2
# 1 0.035194487 Nulliparous
# 2 0.457256373 Nulliparous
# 3 0.027936140 Nulliparous
# 4 0.000877703 Nulliparous
# 5 0.264161953 Nulliparous
# 6 0.377612543 Nulliparous

# %%
# Do calculation and add as column
simpson_merged_fp$delta <- simpson_merged_fp$Simpson_tp2 - simpson_merged_fp$Simpson_tp1
head(simpson_merged_fp)
# Out:
#   Personal_number Sample_ID_tp1 Simpson_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF02740612    0.509929830 Nulliparous FF00653546
# 2 P1f95844        FF02014450    0.007213459 Nulliparous FF02015345
# 3 P3cac7b0        FF02014344    0.407696384 Nulliparous FF00653065
# 4 P3db7da6        FF03816858    0.058367645 Nulliparous FF02014263
# 5 P424fd61        FF02557245    0.248208589 Nulliparous FF02015432
# 6 P4de45e7        FF02015423    0.059153140 Nulliparous FF00653167
#   Simpson_tp2 Group_tp2   delta
# 1 0.035194487 Nulliparous -0.47473534
# 2 0.457256373 Nulliparous  0.45004291
# 3 0.027936140 Nulliparous -0.37976024
# 4 0.000877703 Nulliparous -0.05748994
# 5 0.264161953 Nulliparous  0.01595336
# 6 0.377612543 Nulliparous  0.31845940

# %% [markdown]
# ### Second Pregnancy

# %%
# Create a df with just sp tp1
simpson_sp_tp1 <- tp1_simpson_combined |> filter(Group == "Primiparous")
head(simpson_sp_tp1)
dim(simpson_sp_tp1)
# Out:
#   Sample_ID  Simpson     Group       Personal_number
# 1 FF01566745 0.465800685 Primiparous P159f9c8
# 2 FF06039085 0.004737051 Primiparous P1f862a6
# 3 FF06039601 0.001101025 Primiparous P1f95844
# 4 FF06039627 0.418528345 Primiparous P3cac7b0
# 5 FF03817982 0.360012179 Primiparous P3db7da6
# 6 FF05044855 0.571688145 Primiparous P424fd61
# [1] 26  4

# %%
# Create a df with just sp tp2
simpson_sp_tp2 <- tp2_simpson_combined |> filter(Group == "Primiparous")
head(simpson_sp_tp2)
dim(simpson_sp_tp2)
# Out:
#   Sample_ID  Simpson    Group       Personal_number
# 1 FF08440357 0.01933816 Primiparous P159f9c8
# 2 FF04761496 0.63729338 Primiparous P1f95844
# 3 FF08440702 0.33232714 Primiparous P3cac7b0
# 4 FF05024823 0.43680777 Primiparous P3db7da6
# 5 FF06580149 0.06697681 Primiparous P424fd61
# 6 FF01572330 0.45691030 Primiparous P4de45e7
# [1] 16  4

# %%
# Sanity check
unique(simpson_sp_tp1$Group)
table(simpson_sp_tp1$Group)
# Out:
# [1] Primiparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#           0          26

# %%
# Sanity check
unique(simpson_sp_tp2$Group)
table(simpson_sp_tp2$Group)
# Out:
# [1] Primiparous
# Levels: Nulliparous Primiparous
# Nulliparous Primiparous
#           0          16

# %%
# Merge df by Personal num & add sufixes to colnmes
simpson_merged_sp <- merge(simpson_sp_tp1, simpson_sp_tp2, by= "Personal_number", suffixes = c("_tp1", "_tp2"))
dim(simpson_merged_sp)
head(simpson_merged_sp)
# Out:
# [1] 16  7
#   Personal_number Sample_ID_tp1 Simpson_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF01566745    0.465800685 Primiparous FF08440357
# 2 P1f95844        FF06039601    0.001101025 Primiparous FF04761496
# 3 P3cac7b0        FF06039627    0.418528345 Primiparous FF08440702
# 4 P3db7da6        FF03817982    0.360012179 Primiparous FF05024823
# 5 P424fd61        FF05044855    0.571688145 Primiparous FF06580149
# 6 P4de45e7        FF06040007    0.453561160 Primiparous FF01572330
#   Simpson_tp2 Group_tp2
# 1 0.01933816  Primiparous
# 2 0.63729338  Primiparous
# 3 0.33232714  Primiparous
# 4 0.43680777  Primiparous
# 5 0.06697681  Primiparous
# 6 0.45691030  Primiparous

# %%
# Do calculation and add as column
simpson_merged_sp$delta <- simpson_merged_sp$Simpson_tp2 - simpson_merged_sp$Simpson_tp1
head(simpson_merged_sp)
# Out:
#   Personal_number Sample_ID_tp1 Simpson_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF01566745    0.465800685 Primiparous FF08440357
# 2 P1f95844        FF06039601    0.001101025 Primiparous FF04761496
# 3 P3cac7b0        FF06039627    0.418528345 Primiparous FF08440702
# 4 P3db7da6        FF03817982    0.360012179 Primiparous FF05024823
# 5 P424fd61        FF05044855    0.571688145 Primiparous FF06580149
# 6 P4de45e7        FF06040007    0.453561160 Primiparous FF01572330
#   Simpson_tp2 Group_tp2   delta
# 1 0.01933816  Primiparous -0.446462528
# 2 0.63729338  Primiparous  0.636192354
# 3 0.33232714  Primiparous -0.086201201
# 4 0.43680777  Primiparous  0.076795593
# 5 0.06697681  Primiparous -0.504711334
# 6 0.45691030  Primiparous  0.003349142

# %% [markdown]
# ## Plot ---------------------------------------------------------------------------------------------------------------------------------

# %%
simpson_combined_df <- rbind(simpson_merged_fp, simpson_merged_sp)
head(simpson_combined_df)
# Out:
#   Personal_number Sample_ID_tp1 Simpson_tp1 Group_tp1   Sample_ID_tp2
# 1 P159f9c8        FF02740612    0.509929830 Nulliparous FF00653546
# 2 P1f95844        FF02014450    0.007213459 Nulliparous FF02015345
# 3 P3cac7b0        FF02014344    0.407696384 Nulliparous FF00653065
# 4 P3db7da6        FF03816858    0.058367645 Nulliparous FF02014263
# 5 P424fd61        FF02557245    0.248208589 Nulliparous FF02015432
# 6 P4de45e7        FF02015423    0.059153140 Nulliparous FF00653167
#   Simpson_tp2 Group_tp2   delta
# 1 0.035194487 Nulliparous -0.47473534
# 2 0.457256373 Nulliparous  0.45004291
# 3 0.027936140 Nulliparous -0.37976024
# 4 0.000877703 Nulliparous -0.05748994
# 5 0.264161953 Nulliparous  0.01595336
# 6 0.377612543 Nulliparous  0.31845940

# %%
# Long format for easier plotting
df_simpson_long <- simpson_combined_df |>
    select(Personal_number, Simpson_tp1, Simpson_tp2, Group_tp2, delta) |>
pivot_longer(cols = c(Simpson_tp1, Simpson_tp2),
            names_to = "Timepoint", 
            values_to = "Simpson") |>
    mutate(Timepoint = as.factor(ifelse(Timepoint == "Simpson_tp1", "tp1", "tp2")))

# %%
names(df_simpson_long)[2] <- "Group"

# %%
dim(df_simpson_long)
head(df_simpson_long)
# Out:
# [1] 64  5
#   Personal_number Group       delta      Timepoint Simpson
# 1 P159f9c8        Nulliparous -0.4747353 tp1       0.509929830
# 2 P159f9c8        Nulliparous -0.4747353 tp2       0.035194487
# 3 P1f95844        Nulliparous  0.4500429 tp1       0.007213459
# 4 P1f95844        Nulliparous  0.4500429 tp2       0.457256373
# 5 P3cac7b0        Nulliparous -0.3797602 tp1       0.407696384
# 6 P3cac7b0        Nulliparous -0.3797602 tp2       0.027936140

# %%
# Check that pn are correct
df_simpson_long |> filter(Personal_number == "P1a267fa")
# Out:
#      Personal_number Group delta Timepoint Simpson

# %%
plot_simpson <- df_simpson_long |> 
    ggplot(aes(x = Timepoint, y = Simpson, fill = Group)) +
    geom_boxplot(width = 0.15) +
# Handles tp1 half
    geom_violinhalf(alpha = 0.5, flip = c(1,2), data = df_simpson_long |>
                    filter(Timepoint == "tp1"), position = position_nudge(-0.1)
                   ) +
# Handles tp2 half
   geom_violinhalf(alpha = 0.5, flip = c(3,4), data = df_simpson_long |>
                    filter(Timepoint == "tp2"), position = position_nudge(0.1)
                   ) +
# Ensures that only points of the same personal# and Group are connected 
    geom_line(
        data = df_simpson_long |> 
        group_by(Personal_number, Group, Timepoint) |> 
        ungroup(),
        mapping = aes(
        x = ifelse(Timepoint == "tp1", 1.15, 1.85), # Ofset since the geom_jitter is nudged
        y = Simpson,
        group = interaction(Personal_number, Group),
        color = Group
        ),
      alpha = 0.5,
      linewidth = 0.5
            ) +
    geom_jitter(data = df_simpson_long |>
                    filter(Timepoint == "tp1"), position = position_nudge(0.15), shape = 21, alpha = 0.6, size = 2) +
    geom_jitter(data = df_simpson_long |>
                    filter(Timepoint == "tp2"), position = position_nudge(-0.15), shape = 21, alpha = 0.6, size = 2) +
    labs(
        title = "Rain plot of Simpson"
    ) +
    scale_fill_manual(values = dye) +
    scale_colour_manual(values = dye)+
    theme_half_open() +
    annotate("text", x = Inf, y = Inf, label="p-value = ns", hjust = -0.15, vjust = 20, size = 4.5) +
# Prevents ggplot from cutting of elements outside plot area
    coord_cartesian(clip = "off") +
    theme(
        legend.box.background = element_rect(color = "Black", size = 0.5),
        legend.box.margin = margin(4, 4, 4, 4),
        legend.title = element_text(face = "bold", size = 15),
        title = element_text(size = 18),
        axis.title.y = element_text(size = 15, face = "bold"),
        axis.title.x = element_text(size = 15, face = "bold"),
        panel.grid.major = element_line(colour = "lightgrey"),
        panel.grid.minor = element_line(colour = "lightgrey")
    )
plot_simpson
# Out:
# plot without title

# %% [markdown]
# ## Significance --------------------------------------------------------------------------------------------------------------------------

# %%
# Create a wide table
# Select variables of interest
simpson_wide_delta <- df_simpson_long |> filter(Timepoint == "tp2") |> 
    select(Personal_number, Group, delta) |> 
    pivot_wider(
    names_from = Group,
    values_from = delta)

# %%
head(simpson_wide_delta)
# Out:
#   Personal_number Nulliparous Primiparous
# 1 P159f9c8        -0.47473534 -0.446462528
# 2 P1f95844         0.45004291  0.636192354
# 3 P3cac7b0        -0.37976024 -0.086201201
# 4 P3db7da6        -0.05748994  0.076795593
# 5 P424fd61         0.01595336 -0.504711334
# 6 P4de45e7         0.31845940  0.003349142

# %%
simpson_wide_delta <- simpson_wide_delta |> rename(Nulliparous_delta = Nulliparous)
simpson_wide_delta <- simpson_wide_delta |> rename(Primiparous_delta = Primiparous)
head(simpson_wide_delta)
dim(simpson_wide_delta)
# Out:
#   Personal_number Nulliparous_delta Primiparous_delta
# 1 P159f9c8        -0.47473534       -0.446462528
# 2 P1f95844         0.45004291        0.636192354
# 3 P3cac7b0        -0.37976024       -0.086201201
# 4 P3db7da6        -0.05748994        0.076795593
# 5 P424fd61         0.01595336       -0.504711334
# 6 P4de45e7         0.31845940        0.003349142
# [1] 16  3

# %%
simpson_wide_delta$difference <- simpson_wide_delta$Primiparous_delta - simpson_wide_delta$Nulliparous_delta
shapiro.test(simpson_wide_delta$difference)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  simpson_wide_delta$difference
# W = 0.90209, p-value = 0.08682

# %%
# parametric

# %%
# Plot distribution
simpson_wide_delta |> ggplot(aes(x = difference)) +
    geom_histogram( binwidth = 0.1, position = "identity", fill = "slateblue", col = "black") +
    labs(
    title = "Histogram of delta Simpson difference",
    x = "Difference",
    y = "Frequency"
  ) + 
  scale_y_continuous(
    # Don't expand y scale at the lower end
    expand = expansion(mult = c(0, 0.05))
  ) +
  theme_half_open()
# Out:
# plot without title

# %%
test_simpson <- t.test(Pair(Nulliparous_delta, Primiparous_delta) ~1, data = simpson_wide_delta)
test_simpson
evenness_p <- test_simpson$p.value
# Out:
# 	Paired t-test
#
# data:  Pair(Nulliparous_delta, Primiparous_delta)
# t = -0.15056, df = 15, p-value = 0.8823
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  -0.2589008  0.2247372
# sample estimates:
# mean difference
#     -0.01708181

# %% [markdown]
# # $\Delta \Delta \alpha$=====================================================================================================================================

# %%
t.test(Pair(Nulliparous_delta, Primiparous_delta) ~ 1,data = even_wide_delta)
# Out:
# 	Paired t-test
#
# data:  Pair(Nulliparous_delta, Primiparous_delta)
# t = -0.15736, df = 15, p-value = 0.8771
# alternative hypothesis: true mean difference is not equal to 0
# 95 percent confidence interval:
#  -0.1979277  0.1707120
# sample estimates:
# mean difference
#     -0.01360783

# %% [markdown]
# # Combined plot ------------------------------------------------------------------------------------------------------------------------------

# %%
(plot_shannon | plot_simpson) / (plot_richness | plot_evenness)
# Out:
# plot without title
